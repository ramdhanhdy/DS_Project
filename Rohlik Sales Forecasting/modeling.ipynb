# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd
import datetime as dt
import seaborn as sns
from colorama import Style, Fore
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, ElasticNet
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler, SplineTransformer, FunctionTransformer
from category_encoders import OneHotEncoder, TargetEncoder
from datetime import datetime
from lightgbm import LGBMRegressor
from scipy.optimize import differential_evolution, minimize
from xgboost import XGBRegressor
from sklearn.pipeline import make_pipeline, Pipeline
import gc
from scipy.signal import periodogram
from scipy.stats import kurtosis
from statsmodels.tsa.deterministic import DeterministicProcess, CalendarFourier
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
from sklearn.base import clone, BaseEstimator, TransformerMixin
from matplotlib.ticker import MaxNLocator
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import PredictionErrorDisplay, mean_absolute_error
import os
from sklearn.kernel_approximation import Nystroem

# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Data Preprocessing

# %%
# Load datasets
def load_data(file_path, parse_dates=None):
    """Load a CSV file into a DataFrame."""
    return pd.read_csv(file_path, parse_dates=parse_dates)

# Merge datasets
def merge_datasets(base_df, merge_df, on_columns, how='left'):
    """Merge two DataFrames."""
    return pd.merge(base_df, merge_df, how=how, on=on_columns)

def preprocess_data(sales_train, sales_test, inventory, calendar):
    """Perform preprocessing steps: merging, indexing, and cleaning."""
    # Merge inventory data first
    sales_train = merge_datasets(
        sales_train, 
        inventory,
        on_columns=['unique_id', 'warehouse']
    )
    sales_test = merge_datasets(
        sales_test, 
        inventory,
        on_columns=['unique_id', 'warehouse']
    )
    
    # Merge calendar data
    sales_train = merge_datasets(
        sales_train,
        calendar,
        on_columns=['date', 'warehouse']
    )
    sales_test = merge_datasets(
        sales_test,
        calendar,
        on_columns=['date', 'warehouse']
    )
    
    # Set index and sort
    for df in [sales_train, sales_test]:
        df.set_index('date', inplace=True)
        df.sort_index(inplace=True)
    
    # Drop unnecessary columns
    sales_train.drop(['availability'], axis=1, inplace=True, errors='ignore')
    
    return sales_train, sales_test

# Handle categorical features
def process_categorical_columns(sales_train, sales_test, cat_cols):
    """Handle categorical columns by ensuring consistent categories."""
    for c in cat_cols:
        train_unique = sales_train[c].fillna('None').astype(str).unique()
        test_unique = sales_test[c].fillna('None').astype(str).unique()
        diff_values = np.setdiff1d(test_unique, train_unique)
        
        if diff_values.size > 0:
            print(f"Unseen categories in test for {c}: {diff_values}")
            sales_train.loc[~sales_train[c].isin(diff_values), c] = 'None'
        
        sales_train[c] = sales_train[c].astype('category')
        sales_test[c] = sales_test[c].astype('category')

    return sales_train, sales_test

# Handle missing values
def handle_missing_values(sales_train):
    """Handle missing values in the sales_train DataFrame."""
    # Analyze missing data
    missing_analysis = (
        sales_train.loc[sales_train['sales'].isnull()]
        .reset_index()
        .groupby(['warehouse'], observed=False)
        .agg(
            size=('warehouse', 'size'),
            min_date=('date', 'min'),
            max_date=('date', 'max'),
            days=('date', lambda x: x.max() - x.min()),
            split_date=('date', lambda x: list(np.unique(x.dt.strftime('%Y-%m-%d'))))
        )
        .dropna()
    )
    print(missing_analysis)
    
    # Fill missing values
    sales_train['sales'] = sales_train['sales'].fillna(0)
    sales_train['total_orders'] = sales_train['total_orders'].fillna(0)
    sales_train['sell_price_main'] = sales_train['sell_price_main'].interpolate()
    
    return sales_train

# %%
from category_encoders import CatBoostEncoder, TargetEncoder

def encode_product_id(df, target_col, sigma=0.1):
    """
    Encodes the 'product_unique_id' column using CatBoostEncoder with regularization.
    """
    encoder = CatBoostEncoder(cols=['product_unique_id'], sigma=sigma)
    df['product_unique_id'] = encoder.fit_transform(df['product_unique_id'], df[target_col])
    return df

def encode_warehouse(df, target_col, smoothing=10):
    """
    Encodes the 'warehouse' column using TargetEncoder with smoothing.
    """
    warehouse_encoder = TargetEncoder(cols=['warehouse'], smoothing=smoothing)
    df['warehouse'] = warehouse_encoder.fit_transform(df['warehouse'], df[target_col])
    return df

def encode_hierarchical_categories(df, target_col, levels, smoothing=5):
    """
    Encodes hierarchical category columns (e.g., L1 → L4) using TargetEncoder with smoothing.
    """
    for level in levels:
        col = f"{level}_category_name_en"
        encoder = TargetEncoder(cols=[col], smoothing=smoothing)
        df[f"{col}"] = encoder.fit_transform(df[col], df[target_col])
    return df


def main_encoding_pipeline(df):
    """
    Main encoding pipeline for the dataset.
    Applies all encoding methods: product ID, warehouse, hierarchical categories, and holiday frequency.
    """
    target_col = 'sales'
    hierarchical_levels = ['L1', 'L2', 'L3', 'L4']
    
    # Encode product_unique_id
    df = encode_product_id(df, target_col)
    
    # Encode warehouse
    df = encode_warehouse(df, target_col)
    
    # Encode hierarchical categories
    df = encode_hierarchical_categories(df, target_col, hierarchical_levels)

    df = df.drop('holiday_name', axis=1)
    
    return df

def propagate_encodings(train_df, test_df):
    """
    Propagates encodings from training data to test data.
    """
    # Product ID encoding
    product_encoder = CatBoostEncoder(cols=['product_unique_id'])
    product_encoder.fit(train_df['product_unique_id'], train_df['sales'])
    test_df['product_unique_id'] = product_encoder.transform(test_df['product_unique_id'])

    # Warehouse encoding
    warehouse_encoder = TargetEncoder(cols=['warehouse'])
    warehouse_encoder.fit(train_df['warehouse'], train_df['sales'])
    test_df['warehouse'] = warehouse_encoder.transform(test_df['warehouse'])

    # Hierarchical categories
    for level in ['L1', 'L2', 'L3', 'L4']:
        col = f"{level}_category_name_en"
        encoder = TargetEncoder(cols=[col])
        encoder.fit(train_df[col], train_df['sales'])
        test_df[f"{col}"] = encoder.transform(test_df[col])
    
    return test_df

# %%
def preprocessing_pipeline(config):
    """Preprocessing pipeline with encoding integration"""
    # Load raw data
    sales_train = load_data(config['train_path'], parse_dates=['date'])
    sales_test = load_data(config['test_path'], parse_dates=['date'])
    inventory = load_data(config['inventory_path'])
    calendar = load_data(config['calendar_path'], parse_dates=['date'])

    # Core preprocessing
    def _base_preprocessing(df, is_train=True):
        df = merge_datasets(df, inventory, ['unique_id', 'warehouse'])
        df = merge_datasets(df, calendar, ['date', 'warehouse'])
        df = df.set_index('date').sort_index()
        df = df.drop(columns=['availability'], errors='ignore')
        return df

    # Process datasets
    sales_train = _base_preprocessing(sales_train, is_train=True)
    sales_test = _base_preprocessing(sales_test, is_train=False)

    # Handle missing values
    sales_train = handle_missing_values(sales_train)
    
    # Process categorical columns
    cat_cols = ['warehouse', 'L1_category_name_en', 'L2_category_name_en',
                'L3_category_name_en', 'L4_category_name_en']
    sales_train, sales_test = process_categorical_columns(
        sales_train, sales_test, cat_cols
    )

    # Apply encoding pipeline
    sales_train = main_encoding_pipeline(sales_train)
    
    # Propagate encodings to test data
    sales_test = propagate_encodings(sales_train, sales_test)

    # Validate preprocessing
    _validate_preprocessing(sales_train, sales_test)
    
    return sales_train, sales_test

def _validate_preprocessing(train_df, test_df):
    """Validation with encoding checks"""
    # Core columns
    required_columns = [
        'unique_id', 'warehouse', 'sales', 'sell_price_main',
        'type_0_discount', 'L1_category_name_en'
    ]
    
    # Encoded columns
    encoded_columns = [
        'product_unique_id', 'warehouse',
        'L1_category_name_en', 'L2_category_name_en',
        'L3_category_name_en', 'L4_category_name_en'
    ]

    # Check train data
    missing_train = set(required_columns + encoded_columns) - set(train_df.columns)
    if missing_train:
        raise ValueError(f"Missing columns in train: {missing_train}")

    # Check test data (excluding sales)
    missing_test = set(required_columns + encoded_columns) - set(test_df.columns)
    missing_test.discard('sales')  # Sales is expected to be missing in test
    if missing_test:
        raise ValueError(f"Missing columns in test: {missing_test}")

    print("Preprocessing validation passed successfully")

# %%
# 1. Run preprocessing
config = {
    'train_path': 'data/sales_train.csv',
    'test_path': 'data/sales_test.csv',
    'inventory_path': 'data/inventory.csv',
    'calendar_path': 'data/calendar.csv'
}

preprocessed_train, preprocessed_test = preprocessing_pipeline(config)
# Out:
#              size   min_date   max_date    days  \
# warehouse
# Frankfurt_1     6 2021-12-09 2021-12-10  1 days
# Munich_1       46 2021-05-21 2021-07-11 51 days
#
#                                                     split_date
# warehouse
# Frankfurt_1                           [2021-12-09, 2021-12-10]
# Munich_1     [2021-05-21, 2021-05-22, 2021-05-23, 2021-05-2...
# Preprocessing validation passed successfully

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# | Feature              | Encoder                  | Reason                                    |
# |----------------------|--------------------------|------------------------------------------|
# | product_unique_id    | CatBoost/LeaveOneOut    | High cardinality, time-series safety     |
# | warehouse            | Target Encoding         | Moderate cardinality, relationship to sales |
# | L1/L2/L3/L4_category | Target + Smoothing      | Hierarchical structure, stability        |
# | holiday_name         | Frequency Encoding      | Low cardinality, frequency relevance     |
# | Binary features      | Keep as 0/1             | No encoding needed                       |

# %%
import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin

class CreateTimeFeatures(BaseEstimator, TransformerMixin):
    """
    Creates time features from either a datetime column or index
    """
    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df = X.copy()
        
        # Handle datetime index
        if isinstance(df.index, pd.DatetimeIndex):
            date_series = df.index.to_series()  # Convert to Series for consistency
        # Handle date column
        elif 'date' in df.columns:
            date_series = pd.to_datetime(df['date'])
        else:
            raise ValueError("Input must have either DatetimeIndex or 'date' column")

        # Create time features
        df['year'] = date_series.dt.year
        df['month'] = date_series.dt.month
        df['weekday'] = date_series.dt.weekday
        df['week'] = date_series.dt.isocalendar().week.astype(int)
        df['weekend'] = (date_series.dt.weekday >= 5).astype(int)
        df['semiweekly'] = np.where(date_series.dt.weekday < 3, 0, 1)

        # Cyclical features
        df['month_sin'] = np.sin(df['month'] * (2 * np.pi / 12))
        df['month_cos'] = np.cos(df['month'] * (2 * np.pi / 12))
        
        return df

def calculate_aggregates(df, group_col):
    """Calculate aggregates using date column"""
    return (
        df.groupby(group_col, observed=False)
        .agg(
            days_in_sale=('date', 'nunique'),
            purchase_interval=('date', lambda x: (x.max() - x.min()).days)
        )
        .reset_index()
    )

def calculate_date_gaps(df, group_col):
    """Calculate date gaps using date column"""
    df = df.sort_values([group_col, 'date'])
    df['date_diff'] = (
        df.groupby(group_col, observed=False)['date']
        .diff()
        .dt.days
        .fillna(0)
    )
    df['gap'] = df['date_diff'] > 1
    df['gap_group'] = df.groupby(group_col, observed=False)['gap'].cumsum()

    gap_agg_df = (
        df.groupby([group_col, 'gap_group'], observed=False)['date_diff']
        .max()
        .reset_index()
        .groupby(group_col, observed=False)['date_diff']
        .max()
        .rename('days_without_sale')
    )
    return gap_agg_df

def feature_engineering_pipeline(train_df, test_df):
    """Feature engineering pipeline with proper date handling"""

    # 1. Make sure the index is named 'date' if it's a DatetimeIndex
    train_df.index.name = 'date'
    test_df.index.name = 'date'
    
    # 2. Create temporary copies with 'date' column
    train_temp = train_df.reset_index()
    test_temp = test_df.reset_index()

    # 3. Time features
    time_featurizer = CreateTimeFeatures()
    train_temp = time_featurizer.fit_transform(train_temp)
    test_temp = time_featurizer.transform(test_temp)

    # 4. Calculate aggregates
    agg_features = calculate_aggregates(train_temp, 'name')
    train_temp = train_temp.merge(agg_features, on='name', how='left')
    test_temp = test_temp.merge(agg_features, on='name', how='left')

    # 5. Calculate date gaps
    gap_features = calculate_date_gaps(train_temp, 'name')
    train_temp = train_temp.merge(gap_features, on='name', how='left')
    test_temp = test_temp.merge(gap_features, on='name', how='left')

    # 6. Restore index
    # Because we renamed the index above, 'date' is now a valid column
    train_temp = train_temp.set_index('date')
    test_temp = test_temp.set_index('date')

    return train_temp, test_temp


def _validate_feature_engineering(train_df, test_df):
    """Validation for feature engineering outputs"""
    expected_features = [
        'year', 'month', 'weekday', 'days_in_sale',
        'purchase_interval', 'days_without_sale'
    ]
    
    missing_train = set(expected_features) - set(train_df.columns)
    missing_test = set(expected_features) - set(test_df.columns)
    
    if missing_train:
        raise ValueError(f"Missing engineered features in train: {missing_train}")
    if missing_test:
        raise ValueError(f"Missing engineered features in test: {missing_test}")

    print("Feature engineering validation passed successfully")

# %%
# 2. Run feature engineering 
engineered_train, engineered_test = feature_engineering_pipeline(
    preprocessed_train.copy(),
    preprocessed_test.copy()
)

# %%
engineered_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4007419 entries, 2020-08-01 to 2024-06-02
# Data columns (total 41 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   unique_id                    int64
#  1   warehouse                    category
#  2   total_orders                 float64
#  3   sales                        float64
#  4   sell_price_main              float64
#  5   type_0_discount              float64
#  6   type_1_discount              float64
#  7   type_2_discount              float64
#  8   type_3_discount              float64
#  9   type_4_discount              float64
#  10  type_5_discount              float64
#  11  type_6_discount              float64
#  12  product_unique_id            int64
#  13  name                         object
#  14  L1_category_name_en          category
#  15  L2_category_name_en          category
#  16  L3_category_name_en          category
#  17  L4_category_name_en          category
#  18  holiday_name                 category
#  19  holiday                      int64
#  20  shops_closed                 int64
#  21  winter_school_holidays       int64
#  22  school_holidays              int64
#  23  product_unique_id_encoded    float64
#  24  warehouse_encoded            float64
#  25  L1_category_name_en_encoded  float64
#  26  L2_category_name_en_encoded  float64
#  27  L3_category_name_en_encoded  float64
#  28  L4_category_name_en_encoded  float64
#  29  holiday_frequency            float64
#  30  year                         int32
#  31  month                        int32
#  32  weekday                      int32
#  33  week                         int64
#  34  weekend                      int64
#  35  semiweekly                   int64
#  36  month_sin                    float64
#  37  month_cos                    float64
#  38  days_in_sale                 int64
#  39  purchase_interval            int64
#  40  days_without_sale            float64
# dtypes: category(6), float64(20), int32(3), int64(11), object(1)
# memory usage: 1.1+ GB

# %%
test_weights = pd.read_csv('data/test_weights.csv')
target = 'sales'
weight_map = test_weights.set_index('unique_id')['weight'].to_dict()

oofs = {}
scores = {}
test_preds = {}
COMPUTE_TEST = True

def cross_validate(estimator, features, plot_residuals=False, fit_params={}):
    kf = TimeSeriesSplit(n_splits=5,test_size=dt.timedelta(weeks=2).days)
    X = engineered_train[features].copy()
    y = engineered_train[target]
       
    model = clone(estimator)
    val_preds = np.zeros(len(X))
    list_scores = []
    
    for fold, (trx_idx, val_idx) in enumerate(kf.split(X,y,groups=X['warehouse'])):        
        X_train, y_train = X.iloc[trx_idx], y.iloc[trx_idx]
        X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]      
                
        model.fit(X_train.drop('unique_id',axis=1),y_train, **fit_params)
        y_pred = model.predict(X_val.drop('unique_id',axis=1)).clip(0,None)
        val_preds[val_idx] += y_pred
        wmape = mean_absolute_error(y_val,y_pred,sample_weight=X_val["unique_id"].map(weight_map).values)
        list_scores.append(wmape)
        
        print(f' #{fold} - wmae: {wmape}')
        if plot_residuals:
            display = PredictionErrorDisplay.from_predictions(y_val,y_pred)            
            plt.show()
    if isinstance(model,Pipeline):
        name_model = type(model[-1]).__name__
    else:
        name_model = type(model).__name__                              
    

    oofs[name_model] = val_preds
    scores[name_model] = list_scores
    print(f'wmae mean: {np.mean(list_scores)}')   
    
    if COMPUTE_TEST:
        print('Computing Test prediction....')
        model = clone(estimator)
        model.fit(X,y)
        
        test_pred = model.predict(engineered_test[features]).clip(0,None)
        test_preds[name_model] = test_pred
        print('Computing Test prediction - Ok')

# %%
features = engineered_train.drop('sales', axis=1).columns.tolist()

# %%
# Define the pipeline
lgb_pipeline = make_pipeline(
    TargetEncoder(cols=['name']),
    LGBMRegressor(verbosity=-1)
)

# Run cross-validation with filtered features
cross_validate(lgb_pipeline, features)
# Out:
# d:\DS_Project\Rohlik Sales Forecasting\.venv\Lib\site-packages\sklearn\model_selection\_split.py:1242: UserWarning: The groups parameter is ignored by TimeSeriesSplit
#   warnings.warn(
#  #0 - wmae: 18.406316640244796
#  #1 - wmae: 28.10453226028088
#  #2 - wmae: 32.47101624006897
#  #3 - wmae: 21.071137500107394
#  #4 - wmae: 21.662696956610624
# wmae mean: 24.343139919462534
# Computing Test prediction....
# Computing Test prediction - Ok

# %%
# Define the pipeline
xgb_pipeline = make_pipeline(
    TargetEncoder(cols=['name', 'holiday_name']),
    XGBRegressor(verbosity=0, enable_categorical=True)
)

# Run cross-validation with filtered features
cross_validate(xgb_pipeline, filtered_features)

# %%
from catboost import CatBoostRegressor

# Define the pipeline with CatBoost
cat_pipeline = make_pipeline(
    CatBoostRegressor(
        cat_features=['name'],  # Explicitly specify categorical columns
        verbose=1,
        task_type='GPU', 
        allow_writing_files=False
    )
)

# Run cross-validation
cross_validate(cat_pipeline, features)
# Out:
# d:\DS_Project\Rohlik Sales Forecasting\.venv\Lib\site-packages\sklearn\model_selection\_split.py:1242: UserWarning: The groups parameter is ignored by TimeSeriesSplit
#   warnings.warn(
# Learning rate set to 0.119753
# 0:	learn: 325.3174681	total: 145ms	remaining: 2m 25s
# 1:	learn: 295.2950363	total: 277ms	remaining: 2m 18s
# 2:	learn: 269.2490765	total: 406ms	remaining: 2m 14s
# 3:	learn: 247.1958899	total: 551ms	remaining: 2m 17s
# 4:	learn: 228.0744097	total: 689ms	remaining: 2m 17s
# 5:	learn: 211.8256781	total: 813ms	remaining: 2m 14s
# 6:	learn: 197.8755623	total: 941ms	remaining: 2m 13s
# 7:	learn: 186.1555941	total: 1.08s	remaining: 2m 13s
# 8:	learn: 175.9763769	total: 1.21s	remaining: 2m 12s
# 9:	learn: 166.5917363	total: 1.36s	remaining: 2m 14s
# 10:	learn: 159.2522337	total: 1.49s	remaining: 2m 14s
# 11:	learn: 152.3825020	total: 1.63s	remaining: 2m 14s
# 12:	learn: 146.5922973	total: 1.76s	remaining: 2m 13s
# 13:	learn: 141.4759141	total: 1.91s	remaining: 2m 14s
# 14:	learn: 136.6579204	total: 2.04s	remaining: 2m 13s
# 15:	learn: 133.0060424	total: 2.17s	remaining: 2m 13s
# 16:	learn: 129.7165157	total: 2.31s	remaining: 2m 13s
# 17:	learn: 126.4466593	total: 2.46s	remaining: 2m 13s
# 18:	learn: 124.0494787	total: 2.59s	remaining: 2m 13s
# 19:	learn: 121.7491632	total: 2.71s	remaining: 2m 12s
# 20:	learn: 119.9032115	total: 2.85s	remaining: 2m 12s
# 21:	learn: 117.9785744	total: 2.98s	remaining: 2m 12s
# 22:	learn: 116.5816333	total: 3.11s	remaining: 2m 12s
# 23:	learn: 115.2896946	total: 3.25s	remaining: 2m 12s
# 24:	learn: 114.3596789	total: 3.39s	remaining: 2m 12s
# 25:	learn: 113.3064672	total: 3.53s	remaining: 2m 12s
# 26:	learn: 112.3593232	total: 3.67s	remaining: 2m 12s
# 27:	learn: 111.6832404	total: 3.81s	remaining: 2m 12s
# 28:	learn: 110.9686239	total: 3.94s	remaining: 2m 11s
# 29:	learn: 110.3613680	total: 4.07s	remaining: 2m 11s
# 30:	learn: 109.8681976	total: 4.21s	remaining: 2m 11s
# 31:	learn: 109.4126680	total: 4.34s	remaining: 2m 11s
# 350:	learn: 72.6044713	total: 47.6s	remaining: 1m 28s
# 351:	learn: 72.5753381	total: 47.8s	remaining: 1m 27s
# 352:	learn: 72.5564637	total: 47.9s	remaining: 1m 27s
# 353:	learn: 72.5316236	total: 48s	remaining: 1m 27s
# 354:	learn: 72.5142706	total: 48.2s	remaining: 1m 27s
# 355:	learn: 72.4940655	total: 48.3s	remaining: 1m 27s
# 356:	learn: 72.4577716	total: 48.4s	remaining: 1m 27s
# 357:	learn: 72.4320616	total: 48.6s	remaining: 1m 27s
# 358:	learn: 72.3307551	total: 48.7s	remaining: 1m 26s
# 359:	learn: 72.3011689	total: 48.9s	remaining: 1m 26s
# 360:	learn: 72.2742293	total: 49s	remaining: 1m 26s
# 361:	learn: 72.2470993	total: 49.1s	remaining: 1m 26s
# 362:	learn: 72.2183280	total: 49.3s	remaining: 1m 26s
# 363:	learn: 72.1991054	total: 49.4s	remaining: 1m 26s
# 364:	learn: 72.1071573	total: 49.5s	remaining: 1m 26s
# 365:	learn: 72.0891599	total: 49.7s	remaining: 1m 26s
# 366:	learn: 72.0641658	total: 49.8s	remaining: 1m 25s
# 367:	learn: 72.0226103	total: 50s	remaining: 1m 25s
# 368:	learn: 71.9891457	total: 50.1s	remaining: 1m 25s
# 369:	learn: 71.9386460	total: 50.3s	remaining: 1m 25s
# 370:	learn: 71.9193557	total: 50.4s	remaining: 1m 25s
# 371:	learn: 71.8346552	total: 50.5s	remaining: 1m 25s
# 372:	learn: 71.8125794	total: 50.6s	remaining: 1m 25s
# 373:	learn: 71.7915076	total: 50.8s	remaining: 1m 25s
# 374:	learn: 71.7529603	total: 50.9s	remaining: 1m 24s
# 375:	learn: 71.7295911	total: 51.1s	remaining: 1m 24s
# 376:	learn: 71.6896988	total: 51.2s	remaining: 1m 24s
# 377:	learn: 71.6710795	total: 51.4s	remaining: 1m 24s
# 378:	learn: 71.6561357	total: 51.5s	remaining: 1m 24s
# 379:	learn: 71.6424870	total: 51.7s	remaining: 1m 24s
# 380:	learn: 71.6143185	total: 51.8s	remaining: 1m 24s
# 381:	learn: 71.5665679	total: 51.9s	remaining: 1m 24s
# 382:	learn: 71.5402339	total: 52.1s	remaining: 1m 23s
# 383:	learn: 71.5250984	total: 52.2s	remaining: 1m 23s
# 384:	learn: 71.4983954	total: 52.4s	remaining: 1m 23s
# 385:	learn: 71.4784036	total: 52.5s	remaining: 1m 23s
# 386:	learn: 71.4284157	total: 52.6s	remaining: 1m 23s
# 387:	learn: 71.4008677	total: 52.8s	remaining: 1m 23s
# 388:	learn: 71.3788296	total: 52.9s	remaining: 1m 23s
# 389:	learn: 71.3585357	total: 53.1s	remaining: 1m 22s
# 390:	learn: 71.3136023	total: 53.2s	remaining: 1m 22s
# 391:	learn: 71.2973900	total: 53.3s	remaining: 1m 22s
# 392:	learn: 71.2867232	total: 53.5s	remaining: 1m 22s
# 393:	learn: 71.2684218	total: 53.6s	remaining: 1m 22s
# 394:	learn: 71.2504240	total: 53.8s	remaining: 1m 22s
# 441:	learn: 70.0691141	total: 1m	remaining: 1m 16s
# 442:	learn: 70.0516289	total: 1m	remaining: 1m 16s
# 443:	learn: 70.0339169	total: 1m	remaining: 1m 16s
# 444:	learn: 70.0084409	total: 1m	remaining: 1m 16s
# 445:	learn: 69.9493444	total: 1m 1s	remaining: 1m 15s
# 446:	learn: 69.9334481	total: 1m 1s	remaining: 1m 15s
# 447:	learn: 69.9232164	total: 1m 1s	remaining: 1m 15s
# 448:	learn: 69.8924136	total: 1m 1s	remaining: 1m 15s
# 449:	learn: 69.8753377	total: 1m 1s	remaining: 1m 15s
# 450:	learn: 69.8529353	total: 1m 1s	remaining: 1m 15s
# 451:	learn: 69.8369658	total: 1m 1s	remaining: 1m 15s
# 452:	learn: 69.8116046	total: 1m 2s	remaining: 1m 14s
# 453:	learn: 69.7941209	total: 1m 2s	remaining: 1m 14s
# 454:	learn: 69.7739338	total: 1m 2s	remaining: 1m 14s
# 455:	learn: 69.7540375	total: 1m 2s	remaining: 1m 14s
# 456:	learn: 69.7397345	total: 1m 2s	remaining: 1m 14s
# 457:	learn: 69.7247652	total: 1m 2s	remaining: 1m 14s
# 458:	learn: 69.7096277	total: 1m 2s	remaining: 1m 14s
# 459:	learn: 69.6620828	total: 1m 2s	remaining: 1m 13s
# 460:	learn: 69.6371790	total: 1m 3s	remaining: 1m 13s
# 461:	learn: 69.6122406	total: 1m 3s	remaining: 1m 13s
# 462:	learn: 69.5859456	total: 1m 3s	remaining: 1m 13s
# 463:	learn: 69.5772494	total: 1m 3s	remaining: 1m 13s
# 464:	learn: 69.5613855	total: 1m 3s	remaining: 1m 13s
# 465:	learn: 69.5426741	total: 1m 3s	remaining: 1m 13s
# 466:	learn: 69.5256777	total: 1m 3s	remaining: 1m 12s
# 467:	learn: 69.5062803	total: 1m 4s	remaining: 1m 12s
# 468:	learn: 69.4841708	total: 1m 4s	remaining: 1m 12s
# 469:	learn: 69.4707575	total: 1m 4s	remaining: 1m 12s
# 470:	learn: 69.4575771	total: 1m 4s	remaining: 1m 12s
# 471:	learn: 69.4355772	total: 1m 4s	remaining: 1m 12s
# 472:	learn: 69.4127641	total: 1m 4s	remaining: 1m 12s
# 473:	learn: 69.4015573	total: 1m 4s	remaining: 1m 12s
# 474:	learn: 69.3879697	total: 1m 5s	remaining: 1m 11s
# 475:	learn: 69.3660656	total: 1m 5s	remaining: 1m 11s
# 476:	learn: 69.3477695	total: 1m 5s	remaining: 1m 11s
# 477:	learn: 69.3314846	total: 1m 5s	remaining: 1m 11s
# 478:	learn: 69.3182592	total: 1m 5s	remaining: 1m 11s
# 479:	learn: 69.2749497	total: 1m 5s	remaining: 1m 11s
# 480:	learn: 69.2642481	total: 1m 5s	remaining: 1m 11s
# 481:	learn: 69.2489915	total: 1m 6s	remaining: 1m 10s
# 482:	learn: 69.2244522	total: 1m 6s	remaining: 1m 10s
# 483:	learn: 69.2067500	total: 1m 6s	remaining: 1m 10s
# 484:	learn: 69.1905131	total: 1m 6s	remaining: 1m 10s
# 485:	learn: 69.1758978	total: 1m 6s	remaining: 1m 10s
# 486:	learn: 69.1557482	total: 1m 6s	remaining: 1m 10s
# 487:	learn: 69.1414508	total: 1m 6s	remaining: 1m 10s
# 488:	learn: 69.1290208	total: 1m 7s	remaining: 1m 10s
# 489:	learn: 69.1135569	total: 1m 7s	remaining: 1m 9s
# 490:	learn: 69.0948167	total: 1m 7s	remaining: 1m 9s
# 491:	learn: 69.0844127	total: 1m 7s	remaining: 1m 9s
# 492:	learn: 69.0742217	total: 1m 7s	remaining: 1m 9s
# 493:	learn: 69.0563441	total: 1m 7s	remaining: 1m 9s
# 494:	learn: 69.0375328	total: 1m 7s	remaining: 1m 9s
# 495:	learn: 69.0142994	total: 1m 7s	remaining: 1m 9s
# 496:	learn: 68.9984876	total: 1m 8s	remaining: 1m 8s
# 497:	learn: 68.9879394	total: 1m 8s	remaining: 1m 8s
# 498:	learn: 68.9743000	total: 1m 8s	remaining: 1m 8s
# 499:	learn: 68.9415832	total: 1m 8s	remaining: 1m 8s
# 500:	learn: 68.9295287	total: 1m 8s	remaining: 1m 8s
# 501:	learn: 68.9082168	total: 1m 8s	remaining: 1m 8s
# 502:	learn: 68.8977476	total: 1m 8s	remaining: 1m 8s
# 503:	learn: 68.8889793	total: 1m 9s	remaining: 1m 7s
# 504:	learn: 68.8722706	total: 1m 9s	remaining: 1m 7s
# 505:	learn: 68.8629425	total: 1m 9s	remaining: 1m 7s
# 506:	learn: 68.8579885	total: 1m 9s	remaining: 1m 7s
# 507:	learn: 68.8441563	total: 1m 9s	remaining: 1m 7s
# 508:	learn: 68.8299798	total: 1m 9s	remaining: 1m 7s
# 509:	learn: 68.8101114	total: 1m 9s	remaining: 1m 7s
# 510:	learn: 68.7950215	total: 1m 9s	remaining: 1m 6s
# 511:	learn: 68.7823432	total: 1m 10s	remaining: 1m 6s
# 512:	learn: 68.7596590	total: 1m 10s	remaining: 1m 6s
# 513:	learn: 68.7502785	total: 1m 10s	remaining: 1m 6s
# 514:	learn: 68.7367517	total: 1m 10s	remaining: 1m 6s
# 515:	learn: 68.7259477	total: 1m 10s	remaining: 1m 6s
# 516:	learn: 68.7173138	total: 1m 10s	remaining: 1m 6s
# 517:	learn: 68.6960737	total: 1m 10s	remaining: 1m 5s
# 518:	learn: 68.6770186	total: 1m 11s	remaining: 1m 5s
# 519:	learn: 68.6625694	total: 1m 11s	remaining: 1m 5s
# 520:	learn: 68.6385166	total: 1m 11s	remaining: 1m 5s
# 521:	learn: 68.6247370	total: 1m 11s	remaining: 1m 5s
# 522:	learn: 68.6107013	total: 1m 11s	remaining: 1m 5s
# 523:	learn: 68.6006485	total: 1m 11s	remaining: 1m 5s
# 524:	learn: 68.5871072	total: 1m 11s	remaining: 1m 5s
# 525:	learn: 68.5557376	total: 1m 11s	remaining: 1m 4s
# 526:	learn: 68.5413598	total: 1m 12s	remaining: 1m 4s
# 527:	learn: 68.5319941	total: 1m 12s	remaining: 1m 4s
# 528:	learn: 68.5175516	total: 1m 12s	remaining: 1m 4s
# 529:	learn: 68.5020653	total: 1m 12s	remaining: 1m 4s
# 530:	learn: 68.4911571	total: 1m 12s	remaining: 1m 4s
# 531:	learn: 68.4779374	total: 1m 12s	remaining: 1m 4s
# 532:	learn: 68.4667231	total: 1m 12s	remaining: 1m 3s
# 533:	learn: 68.4459504	total: 1m 13s	remaining: 1m 3s
# 534:	learn: 68.4253020	total: 1m 13s	remaining: 1m 3s
# 535:	learn: 68.4075013	total: 1m 13s	remaining: 1m 3s
# 536:	learn: 68.3962120	total: 1m 13s	remaining: 1m 3s
# 537:	learn: 68.3860305	total: 1m 13s	remaining: 1m 3s
# 538:	learn: 68.3683317	total: 1m 13s	remaining: 1m 3s
# 539:	learn: 68.3586545	total: 1m 13s	remaining: 1m 2s
# 540:	learn: 68.3423059	total: 1m 14s	remaining: 1m 2s
# 541:	learn: 68.3328643	total: 1m 14s	remaining: 1m 2s
# 542:	learn: 68.3106706	total: 1m 14s	remaining: 1m 2s
# 543:	learn: 68.2928961	total: 1m 14s	remaining: 1m 2s
# 544:	learn: 68.2840801	total: 1m 14s	remaining: 1m 2s
# 545:	learn: 68.2754838	total: 1m 14s	remaining: 1m 2s
# 546:	learn: 68.2700830	total: 1m 14s	remaining: 1m 2s
# 547:	learn: 68.2576965	total: 1m 15s	remaining: 1m 1s
# 548:	learn: 68.2447948	total: 1m 15s	remaining: 1m 1s
# 549:	learn: 68.2284114	total: 1m 15s	remaining: 1m 1s
# 550:	learn: 68.2152569	total: 1m 15s	remaining: 1m 1s
# 551:	learn: 68.2088248	total: 1m 15s	remaining: 1m 1s
# 552:	learn: 68.1982182	total: 1m 15s	remaining: 1m 1s
# 553:	learn: 68.1533758	total: 1m 15s	remaining: 1m 1s
# 554:	learn: 68.1469791	total: 1m 15s	remaining: 1m
# 555:	learn: 68.1323913	total: 1m 16s	remaining: 1m
# 556:	learn: 68.1234532	total: 1m 16s	remaining: 1m
# 557:	learn: 68.1070594	total: 1m 16s	remaining: 1m
# 558:	learn: 68.0889016	total: 1m 16s	remaining: 1m
# 559:	learn: 68.0781600	total: 1m 16s	remaining: 1m
# 560:	learn: 68.0656860	total: 1m 16s	remaining: 1m
# 561:	learn: 68.0560333	total: 1m 16s	remaining: 59.9s
# 562:	learn: 68.0384290	total: 1m 17s	remaining: 59.8s
# 563:	learn: 68.0280738	total: 1m 17s	remaining: 59.6s
# 564:	learn: 68.0156808	total: 1m 17s	remaining: 59.5s
# 565:	learn: 68.0054423	total: 1m 17s	remaining: 59.4s
# 566:	learn: 67.9949168	total: 1m 17s	remaining: 59.2s
# 567:	learn: 67.9786949	total: 1m 17s	remaining: 59.1s
# 568:	learn: 67.9670261	total: 1m 17s	remaining: 59s
# 569:	learn: 67.9562125	total: 1m 17s	remaining: 58.8s
# 570:	learn: 67.9410383	total: 1m 18s	remaining: 58.7s
# 571:	learn: 67.9291561	total: 1m 18s	remaining: 58.5s
# 572:	learn: 67.9146343	total: 1m 18s	remaining: 58.4s
# 573:	learn: 67.9040871	total: 1m 18s	remaining: 58.3s
# 619:	learn: 67.1057925	total: 1m 24s	remaining: 51.9s
# 620:	learn: 67.0965273	total: 1m 24s	remaining: 51.8s
# 621:	learn: 67.0799396	total: 1m 25s	remaining: 51.7s
# 622:	learn: 67.0675619	total: 1m 25s	remaining: 51.5s
# 623:	learn: 67.0629859	total: 1m 25s	remaining: 51.4s
# 624:	learn: 67.0228933	total: 1m 25s	remaining: 51.2s
# 625:	learn: 67.0031298	total: 1m 25s	remaining: 51.1s
# 626:	learn: 66.9888001	total: 1m 25s	remaining: 50.9s
# 627:	learn: 66.9830514	total: 1m 25s	remaining: 50.8s
# 628:	learn: 66.9684542	total: 1m 25s	remaining: 50.7s
# 629:	learn: 66.9622114	total: 1m 26s	remaining: 50.5s
# 630:	learn: 66.9513424	total: 1m 26s	remaining: 50.4s
# 631:	learn: 66.9204509	total: 1m 26s	remaining: 50.3s
# 632:	learn: 66.9065962	total: 1m 26s	remaining: 50.1s
# 633:	learn: 66.8819616	total: 1m 26s	remaining: 50s
# 634:	learn: 66.8582505	total: 1m 26s	remaining: 49.9s
# 635:	learn: 66.8373066	total: 1m 26s	remaining: 49.8s
# 636:	learn: 66.8316327	total: 1m 27s	remaining: 49.6s
# 637:	learn: 66.8109635	total: 1m 27s	remaining: 49.5s
# 638:	learn: 66.7998672	total: 1m 27s	remaining: 49.4s
# 639:	learn: 66.7861444	total: 1m 27s	remaining: 49.2s
# 640:	learn: 66.7750287	total: 1m 27s	remaining: 49.1s
# 641:	learn: 66.7694797	total: 1m 27s	remaining: 49s
# 642:	learn: 66.7597582	total: 1m 27s	remaining: 48.8s
# 643:	learn: 66.7531629	total: 1m 28s	remaining: 48.7s
# 644:	learn: 66.7356782	total: 1m 28s	remaining: 48.5s
# 645:	learn: 66.7236388	total: 1m 28s	remaining: 48.4s
# 646:	learn: 66.7156649	total: 1m 28s	remaining: 48.3s
# 647:	learn: 66.7036716	total: 1m 28s	remaining: 48.2s
# 648:	learn: 66.6921628	total: 1m 28s	remaining: 48s
# 649:	learn: 66.6778507	total: 1m 28s	remaining: 47.9s
# 650:	learn: 66.6251930	total: 1m 29s	remaining: 47.7s
# 651:	learn: 66.6156577	total: 1m 29s	remaining: 47.6s
# 652:	learn: 66.6028868	total: 1m 29s	remaining: 47.5s
# 653:	learn: 66.5957579	total: 1m 29s	remaining: 47.3s
# 654:	learn: 66.5885823	total: 1m 29s	remaining: 47.2s
# 655:	learn: 66.5792681	total: 1m 29s	remaining: 47.1s
# 656:	learn: 66.5684556	total: 1m 29s	remaining: 47s
# 657:	learn: 66.5580407	total: 1m 30s	remaining: 46.8s
# 658:	learn: 66.5416874	total: 1m 30s	remaining: 46.7s
# 659:	learn: 66.5320095	total: 1m 30s	remaining: 46.6s
# 660:	learn: 66.5155116	total: 1m 30s	remaining: 46.4s
# 661:	learn: 66.5089305	total: 1m 30s	remaining: 46.3s
# 662:	learn: 66.4973995	total: 1m 30s	remaining: 46.1s
# 663:	learn: 66.4893678	total: 1m 30s	remaining: 46s
# 664:	learn: 66.4814119	total: 1m 31s	remaining: 45.9s
# 710:	learn: 65.9063029	total: 1m 37s	remaining: 39.6s
# 711:	learn: 65.8982224	total: 1m 37s	remaining: 39.5s
# 712:	learn: 65.8922467	total: 1m 37s	remaining: 39.4s
# 713:	learn: 65.8835361	total: 1m 37s	remaining: 39.2s
# 714:	learn: 65.8750183	total: 1m 38s	remaining: 39.1s
# 715:	learn: 65.8633453	total: 1m 38s	remaining: 39s
# 716:	learn: 65.8553371	total: 1m 38s	remaining: 38.9s
# 717:	learn: 65.8474560	total: 1m 38s	remaining: 38.7s
# 718:	learn: 65.8418210	total: 1m 38s	remaining: 38.6s
# 719:	learn: 65.8360925	total: 1m 38s	remaining: 38.5s
# 720:	learn: 65.8277510	total: 1m 39s	remaining: 38.3s
# 721:	learn: 65.8112979	total: 1m 39s	remaining: 38.2s
# 722:	learn: 65.8013184	total: 1m 39s	remaining: 38.1s
# 723:	learn: 65.7929220	total: 1m 39s	remaining: 37.9s
# 724:	learn: 65.7822832	total: 1m 39s	remaining: 37.8s
# 725:	learn: 65.7742263	total: 1m 39s	remaining: 37.7s
# 726:	learn: 65.7605032	total: 1m 39s	remaining: 37.5s
# 727:	learn: 65.7524358	total: 1m 40s	remaining: 37.4s
# 728:	learn: 65.7459649	total: 1m 40s	remaining: 37.3s
# 729:	learn: 65.7307897	total: 1m 40s	remaining: 37.1s
# 730:	learn: 65.7208758	total: 1m 40s	remaining: 37s
# 731:	learn: 65.7137679	total: 1m 40s	remaining: 36.9s
# 732:	learn: 65.7068615	total: 1m 40s	remaining: 36.7s
# 733:	learn: 65.6711668	total: 1m 40s	remaining: 36.6s
# 734:	learn: 65.6642248	total: 1m 41s	remaining: 36.5s
# 735:	learn: 65.6515374	total: 1m 41s	remaining: 36.3s
# 736:	learn: 65.6456949	total: 1m 41s	remaining: 36.2s
# 737:	learn: 65.6322174	total: 1m 41s	remaining: 36.1s
# 738:	learn: 65.6201001	total: 1m 41s	remaining: 35.9s
# 739:	learn: 65.6031119	total: 1m 41s	remaining: 35.8s
# 740:	learn: 65.5926138	total: 1m 42s	remaining: 35.7s
# 741:	learn: 65.5846388	total: 1m 42s	remaining: 35.5s
# 742:	learn: 65.5794800	total: 1m 42s	remaining: 35.4s
# 743:	learn: 65.5705603	total: 1m 42s	remaining: 35.3s
# 744:	learn: 65.5419226	total: 1m 42s	remaining: 35.1s
# 745:	learn: 65.5378210	total: 1m 42s	remaining: 35s
# 746:	learn: 65.5261269	total: 1m 42s	remaining: 34.9s
# 747:	learn: 65.5189745	total: 1m 43s	remaining: 34.7s
# 748:	learn: 65.5118564	total: 1m 43s	remaining: 34.6s
# 749:	learn: 65.5010589	total: 1m 43s	remaining: 34.4s
# 750:	learn: 65.4939506	total: 1m 43s	remaining: 34.3s
# 751:	learn: 65.4852182	total: 1m 43s	remaining: 34.2s
# 752:	learn: 65.4700470	total: 1m 43s	remaining: 34s
# 753:	learn: 65.4658238	total: 1m 43s	remaining: 33.9s
# 754:	learn: 65.4606967	total: 1m 44s	remaining: 33.8s
# 755:	learn: 65.4552881	total: 1m 44s	remaining: 33.6s
# 756:	learn: 65.4434270	total: 1m 44s	remaining: 33.5s
# 757:	learn: 65.4378802	total: 1m 44s	remaining: 33.3s
# 758:	learn: 65.4289354	total: 1m 44s	remaining: 33.2s
# 759:	learn: 65.4173351	total: 1m 44s	remaining: 33.1s
# 760:	learn: 65.4026190	total: 1m 44s	remaining: 32.9s
# 761:	learn: 65.3933586	total: 1m 45s	remaining: 32.8s
# 762:	learn: 65.3802415	total: 1m 45s	remaining: 32.7s
# 763:	learn: 65.3611815	total: 1m 45s	remaining: 32.5s
# 764:	learn: 65.3540247	total: 1m 45s	remaining: 32.4s
# 765:	learn: 65.3440751	total: 1m 45s	remaining: 32.2s
# 766:	learn: 65.3365195	total: 1m 45s	remaining: 32.1s
# 767:	learn: 65.3259883	total: 1m 45s	remaining: 32s
# 768:	learn: 65.3187690	total: 1m 45s	remaining: 31.8s
# 769:	learn: 65.3063118	total: 1m 46s	remaining: 31.7s
# 770:	learn: 65.3008141	total: 1m 46s	remaining: 31.6s
# 771:	learn: 65.2926782	total: 1m 46s	remaining: 31.4s
# 772:	learn: 65.2875160	total: 1m 46s	remaining: 31.3s
# 773:	learn: 65.2809481	total: 1m 46s	remaining: 31.1s
# 774:	learn: 65.2719758	total: 1m 46s	remaining: 31s
# 775:	learn: 65.2617279	total: 1m 47s	remaining: 30.9s
# 776:	learn: 65.2568099	total: 1m 47s	remaining: 30.8s
# 777:	learn: 65.2456333	total: 1m 47s	remaining: 30.6s
# 778:	learn: 65.2389731	total: 1m 47s	remaining: 30.5s
# 779:	learn: 65.2315855	total: 1m 47s	remaining: 30.3s
# 780:	learn: 65.2186807	total: 1m 47s	remaining: 30.2s
# 781:	learn: 65.2096862	total: 1m 47s	remaining: 30.1s
# 782:	learn: 65.2011744	total: 1m 48s	remaining: 29.9s
# 783:	learn: 65.1948330	total: 1m 48s	remaining: 29.8s
# 784:	learn: 65.1854294	total: 1m 48s	remaining: 29.7s
# 785:	learn: 65.1777457	total: 1m 48s	remaining: 29.5s
# 786:	learn: 65.1712000	total: 1m 48s	remaining: 29.4s
# 787:	learn: 65.1638322	total: 1m 48s	remaining: 29.3s
# 788:	learn: 65.1570264	total: 1m 48s	remaining: 29.1s
# 789:	learn: 65.1529633	total: 1m 49s	remaining: 29s
# 790:	learn: 65.1457327	total: 1m 49s	remaining: 28.9s
# 791:	learn: 65.1386366	total: 1m 49s	remaining: 28.7s
# 792:	learn: 65.1330757	total: 1m 49s	remaining: 28.6s
# 793:	learn: 65.1288659	total: 1m 49s	remaining: 28.5s
# 794:	learn: 65.1215424	total: 1m 49s	remaining: 28.3s
# 795:	learn: 65.1157014	total: 1m 50s	remaining: 28.2s
# 796:	learn: 65.1105212	total: 1m 50s	remaining: 28.1s
# 797:	learn: 65.0995315	total: 1m 50s	remaining: 27.9s
# 798:	learn: 65.0904282	total: 1m 50s	remaining: 27.8s
# 799:	learn: 65.0821895	total: 1m 50s	remaining: 27.7s
# 800:	learn: 65.0766021	total: 1m 50s	remaining: 27.5s
# 801:	learn: 65.0697439	total: 1m 50s	remaining: 27.4s
# 802:	learn: 65.0542657	total: 1m 51s	remaining: 27.3s
# 803:	learn: 65.0463622	total: 1m 51s	remaining: 27.1s
# 804:	learn: 65.0408385	total: 1m 51s	remaining: 27s
# 805:	learn: 65.0294598	total: 1m 51s	remaining: 26.9s
# 806:	learn: 65.0229582	total: 1m 51s	remaining: 26.7s
# 807:	learn: 64.9900531	total: 1m 51s	remaining: 26.6s
# 808:	learn: 64.9855765	total: 1m 52s	remaining: 26.4s
# 809:	learn: 64.9732462	total: 1m 52s	remaining: 26.3s
# 810:	learn: 64.9667901	total: 1m 52s	remaining: 26.2s
# 811:	learn: 64.9236733	total: 1m 52s	remaining: 26s
# 812:	learn: 64.9042410	total: 1m 52s	remaining: 25.9s
# 813:	learn: 64.8966854	total: 1m 52s	remaining: 25.8s
# 814:	learn: 64.8926868	total: 1m 52s	remaining: 25.6s
# 815:	learn: 64.8839917	total: 1m 53s	remaining: 25.5s
# 816:	learn: 64.8485986	total: 1m 53s	remaining: 25.4s
# 817:	learn: 64.8392257	total: 1m 53s	remaining: 25.2s
# 818:	learn: 64.8335307	total: 1m 53s	remaining: 25.1s
# 819:	learn: 64.8121908	total: 1m 53s	remaining: 24.9s
# 820:	learn: 64.8025681	total: 1m 53s	remaining: 24.8s
# 821:	learn: 64.7921986	total: 1m 53s	remaining: 24.7s
# 822:	learn: 64.7851742	total: 1m 54s	remaining: 24.5s
# 823:	learn: 64.7735040	total: 1m 54s	remaining: 24.4s
# 824:	learn: 64.7657004	total: 1m 54s	remaining: 24.3s
# 825:	learn: 64.7507374	total: 1m 54s	remaining: 24.1s
# 826:	learn: 64.7459582	total: 1m 54s	remaining: 24s
# 827:	learn: 64.7275641	total: 1m 54s	remaining: 23.8s
# 828:	learn: 64.7082092	total: 1m 54s	remaining: 23.7s
# 829:	learn: 64.7026172	total: 1m 55s	remaining: 23.6s
# 830:	learn: 64.6924351	total: 1m 55s	remaining: 23.4s
# 831:	learn: 64.6862394	total: 1m 55s	remaining: 23.3s
# 832:	learn: 64.6776725	total: 1m 55s	remaining: 23.2s
# 833:	learn: 64.6706298	total: 1m 55s	remaining: 23s
# 834:	learn: 64.6618080	total: 1m 55s	remaining: 22.9s
# 835:	learn: 64.6529415	total: 1m 55s	remaining: 22.7s
# 836:	learn: 64.6432457	total: 1m 56s	remaining: 22.6s
# 837:	learn: 64.6257398	total: 1m 56s	remaining: 22.5s
# 838:	learn: 64.6197235	total: 1m 56s	remaining: 22.3s
# 839:	learn: 64.5861124	total: 1m 56s	remaining: 22.2s
# 840:	learn: 64.5774037	total: 1m 56s	remaining: 22.1s
# 841:	learn: 64.5722140	total: 1m 56s	remaining: 21.9s
# 842:	learn: 64.5645562	total: 1m 56s	remaining: 21.8s
# 843:	learn: 64.5561494	total: 1m 57s	remaining: 21.7s
# 844:	learn: 64.5508589	total: 1m 57s	remaining: 21.5s
# 845:	learn: 64.5387682	total: 1m 57s	remaining: 21.4s
# 846:	learn: 64.5351295	total: 1m 57s	remaining: 21.2s
# 847:	learn: 64.5238458	total: 1m 57s	remaining: 21.1s
# 848:	learn: 64.5182536	total: 1m 57s	remaining: 21s
# 849:	learn: 64.5115203	total: 1m 58s	remaining: 20.8s
# 850:	learn: 64.5043307	total: 1m 58s	remaining: 20.7s
# 851:	learn: 64.4975859	total: 1m 58s	remaining: 20.5s
# 852:	learn: 64.4935863	total: 1m 58s	remaining: 20.4s
# 853:	learn: 64.4838289	total: 1m 58s	remaining: 20.3s
# 854:	learn: 64.4702195	total: 1m 58s	remaining: 20.1s
# 855:	learn: 64.4652728	total: 1m 58s	remaining: 20s
# 856:	learn: 64.4595111	total: 1m 59s	remaining: 19.9s
# 857:	learn: 64.4515802	total: 1m 59s	remaining: 19.7s
# 858:	learn: 64.4400955	total: 1m 59s	remaining: 19.6s
# 859:	learn: 64.4337664	total: 1m 59s	remaining: 19.5s
# 860:	learn: 64.4228100	total: 1m 59s	remaining: 19.3s
# 861:	learn: 64.4198410	total: 1m 59s	remaining: 19.2s
# 862:	learn: 64.4013558	total: 1m 59s	remaining: 19s
# 863:	learn: 64.3925130	total: 2m	remaining: 18.9s
# 864:	learn: 64.3884136	total: 2m	remaining: 18.8s
# 865:	learn: 64.3852486	total: 2m	remaining: 18.6s
# 866:	learn: 64.3790094	total: 2m	remaining: 18.5s
# 867:	learn: 64.3717355	total: 2m	remaining: 18.3s
# 868:	learn: 64.3654334	total: 2m	remaining: 18.2s
# 869:	learn: 64.3584379	total: 2m	remaining: 18.1s
# 870:	learn: 64.3508837	total: 2m 1s	remaining: 17.9s
# 871:	learn: 64.3475481	total: 2m 1s	remaining: 17.8s
# 872:	learn: 64.3419803	total: 2m 1s	remaining: 17.7s
# 873:	learn: 64.3341601	total: 2m 1s	remaining: 17.5s
# 874:	learn: 64.3294671	total: 2m 1s	remaining: 17.4s
# 875:	learn: 64.3079003	total: 2m 1s	remaining: 17.2s
# 876:	learn: 64.3003342	total: 2m 1s	remaining: 17.1s
# 877:	learn: 64.2969145	total: 2m 2s	remaining: 17s
# 878:	learn: 64.2881905	total: 2m 2s	remaining: 16.8s
# 879:	learn: 64.2822678	total: 2m 2s	remaining: 16.7s
# 880:	learn: 64.2770641	total: 2m 2s	remaining: 16.6s
# 881:	learn: 64.2614029	total: 2m 2s	remaining: 16.4s
# 882:	learn: 64.2564700	total: 2m 2s	remaining: 16.3s
# 883:	learn: 64.2448131	total: 2m 2s	remaining: 16.1s
# 884:	learn: 64.2385563	total: 2m 3s	remaining: 16s
# 885:	learn: 64.2319527	total: 2m 3s	remaining: 15.9s
# 886:	learn: 64.2271349	total: 2m 3s	remaining: 15.7s
# 887:	learn: 64.2224042	total: 2m 3s	remaining: 15.6s
# 888:	learn: 64.2176195	total: 2m 3s	remaining: 15.4s
# 889:	learn: 64.2111372	total: 2m 3s	remaining: 15.3s
# 890:	learn: 64.1925998	total: 2m 3s	remaining: 15.2s
# 891:	learn: 64.1810747	total: 2m 4s	remaining: 15s
# ...
# 702:	learn: 65.5416971	total: 1m 53s	remaining: 48s
# 703:	learn: 65.5334587	total: 1m 53s	remaining: 47.8s
# 704:	learn: 65.5294385	total: 1m 53s	remaining: 47.6s
# 705:	learn: 65.5174584	total: 1m 54s	remaining: 47.5s
# 706:	learn: 65.5084875	total: 1m 54s	remaining: 47.3s
# 707:	learn: 65.4911468	total: 1m 54s	remaining: 47.1s
# 708:	learn: 65.4684312	total: 1m 54s	remaining: 47s
# 709:	learn: 65.4638840	total: 1m 54s	remaining: 46.8s
# 710:	learn: 65.4537951	total: 1m 54s	remaining: 46.6s
# 711:	learn: 65.4467423	total: 1m 54s	remaining: 46.5s
# 712:	learn: 65.4368928	total: 1m 55s	remaining: 46.3s
# 713:	learn: 65.4222575	total: 1m 55s	remaining: 46.2s
# 714:	learn: 65.4068766	total: 1m 55s	remaining: 46s
# 715:	learn: 65.3968200	total: 1m 55s	remaining: 45.9s
# 716:	learn: 65.3824844	total: 1m 55s	remaining: 45.7s
# 717:	learn: 65.3735829	total: 1m 56s	remaining: 45.6s
# 718:	learn: 65.3635329	total: 1m 56s	remaining: 45.5s
# 719:	learn: 65.3561595	total: 1m 56s	remaining: 45.4s
# 720:	learn: 65.3418483	total: 1m 56s	remaining: 45.2s
# 721:	learn: 65.3245513	total: 1m 56s	remaining: 45s
# 722:	learn: 65.3185565	total: 1m 57s	remaining: 44.9s
# 723:	learn: 65.3106909	total: 1m 57s	remaining: 44.7s
# 724:	learn: 65.3009149	total: 1m 57s	remaining: 44.6s
# 725:	learn: 65.2921177	total: 1m 57s	remaining: 44.4s
# 726:	learn: 65.2615318	total: 1m 57s	remaining: 44.2s
# 727:	learn: 65.2445445	total: 1m 57s	remaining: 44.1s
# 728:	learn: 65.2393590	total: 1m 58s	remaining: 43.9s
# 729:	learn: 65.2228262	total: 1m 58s	remaining: 43.7s
# 730:	learn: 65.2048707	total: 1m 58s	remaining: 43.6s
# 731:	learn: 65.1978655	total: 1m 58s	remaining: 43.4s
# 732:	learn: 65.1894307	total: 1m 58s	remaining: 43.3s
# 733:	learn: 65.1725266	total: 1m 58s	remaining: 43.1s
# 734:	learn: 65.1612024	total: 1m 59s	remaining: 42.9s
# 735:	learn: 65.1543376	total: 1m 59s	remaining: 42.8s
# 736:	learn: 65.1434790	total: 1m 59s	remaining: 42.6s
# 737:	learn: 65.1268180	total: 1m 59s	remaining: 42.5s
# 738:	learn: 65.1203497	total: 1m 59s	remaining: 42.4s
# 739:	learn: 65.1033884	total: 2m	remaining: 42.2s
# 740:	learn: 65.0879577	total: 2m	remaining: 42.1s
# 741:	learn: 65.0830404	total: 2m	remaining: 41.9s
# 742:	learn: 65.0789727	total: 2m	remaining: 41.7s
# 743:	learn: 65.0659220	total: 2m	remaining: 41.6s
# 744:	learn: 65.0592062	total: 2m	remaining: 41.4s
# 745:	learn: 65.0529080	total: 2m 1s	remaining: 41.2s
# 746:	learn: 65.0433839	total: 2m 1s	remaining: 41.1s
# 747:	learn: 65.0203487	total: 2m 1s	remaining: 40.9s
# 748:	learn: 65.0098510	total: 2m 1s	remaining: 40.8s
# 749:	learn: 64.9990450	total: 2m 1s	remaining: 40.6s
# 750:	learn: 64.9843543	total: 2m 1s	remaining: 40.4s
# 751:	learn: 64.9659140	total: 2m 2s	remaining: 40.3s
# 752:	learn: 64.9561077	total: 2m 2s	remaining: 40.1s
# 753:	learn: 64.9437602	total: 2m 2s	remaining: 40s
# 754:	learn: 64.9355226	total: 2m 2s	remaining: 39.8s
# 755:	learn: 64.9245881	total: 2m 2s	remaining: 39.6s
# 756:	learn: 64.9144922	total: 2m 2s	remaining: 39.5s
# 757:	learn: 64.9101640	total: 2m 3s	remaining: 39.3s
# 758:	learn: 64.8855614	total: 2m 3s	remaining: 39.1s
# 759:	learn: 64.8809064	total: 2m 3s	remaining: 39s
# 760:	learn: 64.8620132	total: 2m 3s	remaining: 38.8s
# 761:	learn: 64.8583080	total: 2m 3s	remaining: 38.6s
# 762:	learn: 64.8437391	total: 2m 3s	remaining: 38.5s
# 763:	learn: 64.8396190	total: 2m 4s	remaining: 38.3s
# 764:	learn: 64.8313741	total: 2m 4s	remaining: 38.1s
# 765:	learn: 64.8268808	total: 2m 4s	remaining: 38s
# 766:	learn: 64.8141755	total: 2m 4s	remaining: 37.8s
# 767:	learn: 64.8053084	total: 2m 4s	remaining: 37.7s
# 768:	learn: 64.7947344	total: 2m 4s	remaining: 37.5s
# 769:	learn: 64.7877933	total: 2m 4s	remaining: 37.3s
# 770:	learn: 64.7821629	total: 2m 5s	remaining: 37.2s
# 771:	learn: 64.7766326	total: 2m 5s	remaining: 37s
# 772:	learn: 64.7692003	total: 2m 5s	remaining: 36.8s
# 773:	learn: 64.7633336	total: 2m 5s	remaining: 36.7s
# 774:	learn: 64.7471253	total: 2m 5s	remaining: 36.5s
# 775:	learn: 64.7381029	total: 2m 5s	remaining: 36.4s
# 776:	learn: 64.7124576	total: 2m 6s	remaining: 36.2s
# 777:	learn: 64.6977769	total: 2m 6s	remaining: 36s
# 778:	learn: 64.6927391	total: 2m 6s	remaining: 35.9s
# 779:	learn: 64.6863993	total: 2m 6s	remaining: 35.7s
# 780:	learn: 64.6794741	total: 2m 6s	remaining: 35.5s
# 781:	learn: 64.6729533	total: 2m 6s	remaining: 35.4s
# 782:	learn: 64.6671864	total: 2m 7s	remaining: 35.2s
# 783:	learn: 64.6598799	total: 2m 7s	remaining: 35.1s
# 784:	learn: 64.6370579	total: 2m 7s	remaining: 34.9s
# 785:	learn: 64.6301986	total: 2m 7s	remaining: 34.7s
# 786:	learn: 64.6229472	total: 2m 7s	remaining: 34.6s
# 787:	learn: 64.6149179	total: 2m 7s	remaining: 34.4s
# 788:	learn: 64.5994912	total: 2m 8s	remaining: 34.3s
# 789:	learn: 64.5914233	total: 2m 8s	remaining: 34.1s
# 790:	learn: 64.5845019	total: 2m 8s	remaining: 33.9s
# 791:	learn: 64.5729677	total: 2m 8s	remaining: 33.8s
# 792:	learn: 64.5671584	total: 2m 8s	remaining: 33.6s
# 793:	learn: 64.5602660	total: 2m 8s	remaining: 33.4s
# 794:	learn: 64.5561793	total: 2m 8s	remaining: 33.3s
# 795:	learn: 64.5429061	total: 2m 9s	remaining: 33.1s
# 796:	learn: 64.5385490	total: 2m 9s	remaining: 32.9s
# 797:	learn: 64.5124640	total: 2m 9s	remaining: 32.8s
# 798:	learn: 64.4954319	total: 2m 9s	remaining: 32.6s
# 799:	learn: 64.4900811	total: 2m 9s	remaining: 32.4s
# 800:	learn: 64.4723714	total: 2m 9s	remaining: 32.3s
# 801:	learn: 64.4617547	total: 2m 10s	remaining: 32.1s
# 802:	learn: 64.4514039	total: 2m 10s	remaining: 31.9s
# 803:	learn: 64.4399847	total: 2m 10s	remaining: 31.8s
# 804:	learn: 64.4250218	total: 2m 10s	remaining: 31.6s
# 805:	learn: 64.4167358	total: 2m 10s	remaining: 31.5s
# 806:	learn: 64.4105314	total: 2m 10s	remaining: 31.3s
# 807:	learn: 64.4041956	total: 2m 11s	remaining: 31.1s
# 808:	learn: 64.3942383	total: 2m 11s	remaining: 31s
# 809:	learn: 64.3893513	total: 2m 11s	remaining: 30.8s
# 810:	learn: 64.3836722	total: 2m 11s	remaining: 30.7s
# 811:	learn: 64.3775679	total: 2m 11s	remaining: 30.5s
# 812:	learn: 64.3714630	total: 2m 11s	remaining: 30.3s
# 813:	learn: 64.3513124	total: 2m 12s	remaining: 30.2s
# 814:	learn: 64.3355325	total: 2m 12s	remaining: 30s
# 815:	learn: 64.3218086	total: 2m 12s	remaining: 29.9s
# 816:	learn: 64.3053538	total: 2m 12s	remaining: 29.7s
# 817:	learn: 64.2953634	total: 2m 12s	remaining: 29.5s
# 818:	learn: 64.2861742	total: 2m 12s	remaining: 29.4s
# 819:	learn: 64.2697342	total: 2m 13s	remaining: 29.2s
# 820:	learn: 64.2616767	total: 2m 13s	remaining: 29.1s
# 821:	learn: 64.2487821	total: 2m 13s	remaining: 28.9s
# 822:	learn: 64.2406663	total: 2m 13s	remaining: 28.8s
# 823:	learn: 64.2369332	total: 2m 13s	remaining: 28.6s
# 824:	learn: 64.2152223	total: 2m 14s	remaining: 28.4s
# 825:	learn: 64.2034566	total: 2m 14s	remaining: 28.3s
# 826:	learn: 64.1956276	total: 2m 14s	remaining: 28.1s
# 827:	learn: 64.1920252	total: 2m 14s	remaining: 27.9s
# 828:	learn: 64.1844655	total: 2m 14s	remaining: 27.8s
# 829:	learn: 64.1719895	total: 2m 14s	remaining: 27.6s
# 830:	learn: 64.1681886	total: 2m 15s	remaining: 27.5s
# 831:	learn: 64.1378576	total: 2m 15s	remaining: 27.3s
# 832:	learn: 64.1275899	total: 2m 15s	remaining: 27.1s
# 833:	learn: 64.1230054	total: 2m 15s	remaining: 27s
# 834:	learn: 64.1100053	total: 2m 15s	remaining: 26.8s
# 835:	learn: 64.0946583	total: 2m 15s	remaining: 26.6s
# 836:	learn: 64.0839731	total: 2m 16s	remaining: 26.5s
# 837:	learn: 64.0753717	total: 2m 16s	remaining: 26.3s
# 838:	learn: 64.0687236	total: 2m 16s	remaining: 26.2s
# 839:	learn: 64.0446675	total: 2m 16s	remaining: 26s
# 840:	learn: 64.0358115	total: 2m 16s	remaining: 25.9s
# 841:	learn: 64.0316395	total: 2m 16s	remaining: 25.7s
# 842:	learn: 64.0259127	total: 2m 17s	remaining: 25.5s
# 843:	learn: 63.9995688	total: 2m 17s	remaining: 25.4s
# 844:	learn: 63.9860903	total: 2m 17s	remaining: 25.2s
# 845:	learn: 63.9739031	total: 2m 17s	remaining: 25.1s
# 846:	learn: 63.9620891	total: 2m 17s	remaining: 24.9s
# 847:	learn: 63.9571211	total: 2m 18s	remaining: 24.7s
# 848:	learn: 63.9480512	total: 2m 18s	remaining: 24.6s
# 849:	learn: 63.9438275	total: 2m 18s	remaining: 24.4s
# 850:	learn: 63.9321298	total: 2m 18s	remaining: 24.2s
# 851:	learn: 63.9221350	total: 2m 18s	remaining: 24.1s
# 852:	learn: 63.9173158	total: 2m 18s	remaining: 23.9s
# 853:	learn: 63.9081563	total: 2m 19s	remaining: 23.8s
# 854:	learn: 63.9014808	total: 2m 19s	remaining: 23.6s
# 855:	learn: 63.8949365	total: 2m 19s	remaining: 23.4s
# 856:	learn: 63.8870456	total: 2m 19s	remaining: 23.3s
# 857:	learn: 63.8755296	total: 2m 19s	remaining: 23.1s
# 858:	learn: 63.8721512	total: 2m 19s	remaining: 23s
# 859:	learn: 63.8661820	total: 2m 19s	remaining: 22.8s
# 860:	learn: 63.8569352	total: 2m 20s	remaining: 22.6s
# 861:	learn: 63.8497560	total: 2m 20s	remaining: 22.5s
# 862:	learn: 63.8297429	total: 2m 20s	remaining: 22.3s
# 863:	learn: 63.8246566	total: 2m 20s	remaining: 22.1s
# 864:	learn: 63.8120581	total: 2m 20s	remaining: 22s
# 865:	learn: 63.8051142	total: 2m 20s	remaining: 21.8s
# 866:	learn: 63.8016279	total: 2m 21s	remaining: 21.6s
# 867:	learn: 63.7890970	total: 2m 21s	remaining: 21.5s
# 868:	learn: 63.7818061	total: 2m 21s	remaining: 21.3s
# 869:	learn: 63.7661477	total: 2m 21s	remaining: 21.2s
# 870:	learn: 63.7469381	total: 2m 21s	remaining: 21s
# 871:	learn: 63.7364552	total: 2m 21s	remaining: 20.8s
# 872:	learn: 63.7281057	total: 2m 22s	remaining: 20.7s
# 873:	learn: 63.7213010	total: 2m 22s	remaining: 20.5s
# 874:	learn: 63.7155784	total: 2m 22s	remaining: 20.4s
# 875:	learn: 63.7061692	total: 2m 22s	remaining: 20.2s
# 876:	learn: 63.6978900	total: 2m 22s	remaining: 20s
# 877:	learn: 63.6957036	total: 2m 22s	remaining: 19.9s
# 878:	learn: 63.6875955	total: 2m 23s	remaining: 19.7s
# 879:	learn: 63.6797633	total: 2m 23s	remaining: 19.5s
# 880:	learn: 63.6703990	total: 2m 23s	remaining: 19.4s
# 881:	learn: 63.6655067	total: 2m 23s	remaining: 19.2s
# 882:	learn: 63.6596667	total: 2m 23s	remaining: 19.1s
# 883:	learn: 63.6438257	total: 2m 23s	remaining: 18.9s
# 884:	learn: 63.6345806	total: 2m 24s	remaining: 18.7s
# 885:	learn: 63.6009176	total: 2m 24s	remaining: 18.6s
# 886:	learn: 63.5928195	total: 2m 24s	remaining: 18.4s
# 887:	learn: 63.5879976	total: 2m 24s	remaining: 18.2s
# 888:	learn: 63.5823112	total: 2m 24s	remaining: 18.1s
# 889:	learn: 63.5760174	total: 2m 24s	remaining: 17.9s
# 890:	learn: 63.5557090	total: 2m 25s	remaining: 17.8s
# 891:	learn: 63.5519256	total: 2m 25s	remaining: 17.6s
# 892:	learn: 63.5402724	total: 2m 25s	remaining: 17.4s
# 893:	learn: 63.5204535	total: 2m 25s	remaining: 17.3s
# 894:	learn: 63.5139202	total: 2m 25s	remaining: 17.1s
# 895:	learn: 63.4921955	total: 2m 25s	remaining: 16.9s
# 896:	learn: 63.4857399	total: 2m 26s	remaining: 16.8s
# 897:	learn: 63.4673392	total: 2m 26s	remaining: 16.6s
# 898:	learn: 63.4588174	total: 2m 26s	remaining: 16.4s
# 899:	learn: 63.4542108	total: 2m 26s	remaining: 16.3s
# 900:	learn: 63.4490963	total: 2m 26s	remaining: 16.1s
# 901:	learn: 63.4345200	total: 2m 26s	remaining: 16s
# 902:	learn: 63.4265638	total: 2m 26s	remaining: 15.8s
# 903:	learn: 63.4204863	total: 2m 27s	remaining: 15.6s
# 904:	learn: 63.4163120	total: 2m 27s	remaining: 15.5s
# 905:	learn: 63.4080050	total: 2m 27s	remaining: 15.3s
# 906:	learn: 63.3998440	total: 2m 27s	remaining: 15.1s
# 907:	learn: 63.3907044	total: 2m 27s	remaining: 15s
# 908:	learn: 63.3845750	total: 2m 27s	remaining: 14.8s
# 909:	learn: 63.3773323	total: 2m 28s	remaining: 14.6s
# 910:	learn: 63.3699173	total: 2m 28s	remaining: 14.5s
# 911:	learn: 63.3617191	total: 2m 28s	remaining: 14.3s
# 912:	learn: 63.3541632	total: 2m 28s	remaining: 14.2s
# 913:	learn: 63.3473324	total: 2m 28s	remaining: 14s
# 914:	learn: 63.3424998	total: 2m 28s	remaining: 13.8s
# 915:	learn: 63.3350768	total: 2m 28s	remaining: 13.7s
# 916:	learn: 63.3290025	total: 2m 29s	remaining: 13.5s
# 917:	learn: 63.3128831	total: 2m 29s	remaining: 13.3s
# 918:	learn: 63.3070791	total: 2m 29s	remaining: 13.2s
# 919:	learn: 63.3017692	total: 2m 29s	remaining: 13s
# 920:	learn: 63.2954091	total: 2m 29s	remaining: 12.8s
# 921:	learn: 63.2901547	total: 2m 29s	remaining: 12.7s
# 922:	learn: 63.2834160	total: 2m 30s	remaining: 12.5s
# 923:	learn: 63.2619474	total: 2m 30s	remaining: 12.4s
# 924:	learn: 63.2549107	total: 2m 30s	remaining: 12.2s
# 925:	learn: 63.2441806	total: 2m 30s	remaining: 12s
# 926:	learn: 63.2383400	total: 2m 30s	remaining: 11.9s
# 927:	learn: 63.2250529	total: 2m 30s	remaining: 11.7s
# 928:	learn: 63.2172725	total: 2m 31s	remaining: 11.5s
# 974:	learn: 62.8423864	total: 2m 38s	remaining: 4.06s
# 975:	learn: 62.8340624	total: 2m 38s	remaining: 3.9s
# 976:	learn: 62.8288650	total: 2m 38s	remaining: 3.74s
# 977:	learn: 62.8206979	total: 2m 38s	remaining: 3.57s
# 978:	learn: 62.8109310	total: 2m 39s	remaining: 3.41s
# 979:	learn: 62.8062727	total: 2m 39s	remaining: 3.25s
# 980:	learn: 62.8005461	total: 2m 39s	remaining: 3.09s
# 981:	learn: 62.7926724	total: 2m 39s	remaining: 2.92s
# 982:	learn: 62.7852698	total: 2m 39s	remaining: 2.76s
# 983:	learn: 62.7651798	total: 2m 39s	remaining: 2.6s
# 984:	learn: 62.7589527	total: 2m 39s	remaining: 2.44s
# 985:	learn: 62.7557259	total: 2m 40s	remaining: 2.27s
# 986:	learn: 62.7506421	total: 2m 40s	remaining: 2.11s
# 987:	learn: 62.7492861	total: 2m 40s	remaining: 1.95s
# 988:	learn: 62.7438475	total: 2m 40s	remaining: 1.78s
# 989:	learn: 62.7341582	total: 2m 40s	remaining: 1.62s
# 990:	learn: 62.7301786	total: 2m 40s	remaining: 1.46s
# 991:	learn: 62.7257710	total: 2m 41s	remaining: 1.3s
# 992:	learn: 62.7135019	total: 2m 41s	remaining: 1.14s
# 993:	learn: 62.7074163	total: 2m 41s	remaining: 974ms
# 994:	learn: 62.6987056	total: 2m 41s	remaining: 812ms
# 995:	learn: 62.6924128	total: 2m 41s	remaining: 649ms
# 996:	learn: 62.6875501	total: 2m 41s	remaining: 487ms
# 997:	learn: 62.6840689	total: 2m 41s	remaining: 325ms
# 998:	learn: 62.6770551	total: 2m 42s	remaining: 162ms
# 999:	learn: 62.6445234	total: 2m 42s	remaining: 0us
# Computing Test prediction - Ok

# %%
print(sklearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(sklearn.__version__)
#
# NameError: name 'sklearn' is not defined

# %% [markdown]
# # Submission

# %%
solution = pd.read_csv('data/solution.csv')

# %%
if COMPUTE_TEST:
    solution['sales_hat'] = test_preds['LGBMRegressor'].clip(0,None)
    solution.to_csv('submission_lgbm.csv',index=False)

# %%
solution
# Out:
#                     id   sales_hat
# 0      1226_2024-06-03   79.841788
# 1      1226_2024-06-11   72.054763
# 2      1226_2024-06-13   60.297780
# 3      1226_2024-06-15   64.426296
# 4      1226_2024-06-09  127.571231
# ...                ...         ...
# 47016  4572_2024-06-03  147.586792
# 47017  3735_2024-06-04   63.082169
# 47018  3735_2024-06-03   61.143945
# 47019  2129_2024-06-03   94.349845
# 47020  3030_2024-06-03   68.598025
#
# [47021 rows x 2 columns]

# %%
solution
# Out:
#                     id   sales_hat
# 0      1226_2024-06-03   73.790006
# 1      1226_2024-06-11   58.321924
# 2      1226_2024-06-13   30.570593
# 3      1226_2024-06-15   52.389194
# 4      1226_2024-06-09  146.530344
# ...                ...         ...
# 47016  4572_2024-06-03  129.656772
# 47017  3735_2024-06-04   33.990089
# 47018  3735_2024-06-03   39.295015
# 47019  2129_2024-06-03  108.814379
# 47020  3030_2024-06-03   66.860285
#
# [47021 rows x 2 columns]
