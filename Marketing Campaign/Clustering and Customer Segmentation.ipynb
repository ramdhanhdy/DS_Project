# %% [markdown]
# # Technical Setup

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
# %matplotlib inline
plt.style.use('bmh')

from datetime import datetime
import functools
import gc
from umap import validation



# stats packages
import scipy.stats as stats
from scipy.stats import pointbiserialr
from scipy.stats import chi2_contingency
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform
from sklearn import metrics
from sklearn import preprocessing

from denseclus import DenseClus

# %% [markdown]
# # Data Collection

# %%
df = pd.read_csv('data\df_clean.csv')

# Derive RFM features
def rfm_segments(df):
    # Champions
    if df['Recency_Score'] >= 4 and df['Frequency_Score'] >= 4 and df['Monetary_Score'] >= 4:
        return 'Champions'
    # New
    elif df['Recency_Score'] >= 4 and df['Frequency_Score'] <= 2:
        return 'New'
    # Promising
    elif df['Recency_Score'] >= 3 and df['Frequency_Score'] <= 2:
        return 'Promising'
    # At Risk
    elif df['Recency_Score'] <= 2 and df['Frequency_Score'] >= 3 and df['Monetary_Score'] >= 3:
        return 'At Risk'
    # Can’t Lose Them
    elif df['Recency_Score'] <= 2 and df['Frequency_Score'] >= 4 and df['Monetary_Score'] >= 4:
        return 'Can’t Lose Them'
    # Lost
    else:
        return 'Lost'

df['RFM_Segment'] = df.apply(rfm_segments, axis=1)

print(df.shape)
# Out:
# (2193, 42)

# %%
df
# Out:
#        Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 0     Graduation         Single  58138.0        0         0      663
# 1     Graduation         Single  46344.0        1         1      113
# 2     Graduation       Together  71613.0        0         0      312
# 3     Graduation       Together  26646.0        1         0      139
# 4            PhD        Married  58293.0        1         0      161
# ...          ...            ...      ...      ...       ...      ...
# 2188  Graduation        Married  61223.0        0         1      381
# 2189         PhD       Together  64014.0        2         1       19
# 2190  Graduation       Divorced  56981.0        0         0      155
# 2191      Master       Together  69245.0        0         1      156
# 2192         PhD        Married  52869.0        1         1      622
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 0          635         88              546              172  ...
# 1           11          1                6                2  ...
# 2          426         49              127              111  ...
# 3           11          4               20               10  ...
# 4          173         43              118               46  ...
# ...        ...        ...              ...              ...  ...
# 2188       709         43              182               42  ...
# 2189       406          0               30                0  ...
# 2190       908         48              217               32  ...
# 2191       428         30              214               80  ...
# 2192        84          3               61                2  ...
#
#       Total_Accepted_Campaigns  AcceptedAnyCmp  Engagement_Rate  \
# 0                            1               1        16.666667
# 1                            0               0         0.000000
# 2                            0               0         0.000000
# 3                            0               0         0.000000
# 4                            0               0         0.000000
# ...                        ...             ...              ...
# 2188                         0               0         0.000000
# 2189                         1               1        16.666667
# 2190                         1               1        16.666667
# 2191                         0               0         0.000000
# 2192                         1               1        16.666667
#
#       Total_Purchases  Total_Spending  Spend_per_Purchase  Recency_Score  \
# 0                  25            1617           64.680000              1
# 1                   6              27            4.500000              5
# 2                  21             776           36.952381              3
# 3                   8              53            6.625000              5
# 4                  19             422           22.210526              4
# ...               ...             ...                 ...            ...
# 2188               18            1341           74.500000              3
# 2189               22             444           20.181818              5
# 2190               19            1241           65.315789              4
# 2191               23             843           36.652174              4
# 2192               11             172           15.636364              1
#
#       Frequency_Score  Monetary_Score   Avg_RFM
# 0                   5               5  3.666667
# 1                   1               1  2.333333
# 2                   4               4  3.666667
# 3                   2               1  2.666667
# 4                   4               3  3.666667
# ...               ...             ...       ...
# 2188                4               5  4.000000
# 2189                5               3  4.333333
# 2190                4               5  4.333333
# 2191                5               4  4.333333
# 2192                3               2  2.000000
#
# [2193 rows x 41 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Feature Selection criteria for Clustering algorithm:
#
# **Independence**
# - The fields entered into the clustering algorithm should have a minimal relationship. If not completely independent, then nearly so,
# meaning the correlation between the variables is close to zero. Stated more precisely, the J input fields to the clustering algorithm should form J orthogonal dimensions, to as close as the extent possible. This is important so that each attribute or behavior measured represents a distinct aspect of the customers being segmented, and no particular dimension gains undue attention.
# - An example of dependent input variables would be behavioral attributes
# like number of purchases and total spend. These are dependent because additional purchases naturally imply more spending. A pair that is more independent would be number of purchases and spend per purchase, as one captures
# frequency, and the other captures volume.
#
# **Cardinality of Categorical Features**
# - The number of unique values in a categorical feature should ideally be low for use in clustering algorithms. High cardinality can result in a large number of dimensions post one-hot encoding or dummy variable creation, which can exacerbate the "curse of dimensionality" and lead to inefficient or inaccurate clusters.
# - High cardinality categorical variables are better left for segmentation before or after clustering, or they can be transformed into a lower-dimensional format using techniques like label encoding, target encoding, or embeddings.
# - It is also crucial to consider the distribution of categories within the feature. If a small number of categories account for a significant portion of the observations, it might still be worth including the variable in the clustering algorithm after appropriate transformations

# %% [markdown]
# To satisfy the indepence criteria, correlation matrix will be utilized to pick features which satisfy it. For numerical features, Pearson's r will be used. For categorical features, Cramer's V will be used as metric to measure association strength.

# %%
#defining color palette
sns.palplot(sns.diverging_palette(0, 255, sep=8, n=150, center='dark'))

main_facecolor = '#FFFFFF'
main_facecolor2 = '#0D0D0D'
cmap1 = sns.diverging_palette(230, 20, as_cmap=True)
cmap2 = ["#e27c7c", "#a86464", "#6d4b4b", "#503f3f", "#333333", "#3c4e4b", "#466964", "#599e94", "#6cd4c5"]
cmap3 = sns.diverging_palette(0, 255, sep=1, n=50, center='dark')

# %%
def plot_heatmap(data, title, figsize=(16, 10)):
    mask = np.triu(np.ones_like(data, dtype=bool))
    fig, ax = plt.subplots(figsize=figsize, facecolor=main_facecolor)
    ax.set_facecolor('#f0f0f0')
    ax.grid(False)
    ax.set_title(title, fontsize=14, fontweight='semibold', fontfamily='sans-serif', color="#413f42",
                 bbox=dict(facecolor='#f0f0f0', edgecolor='#d5d3d6', boxstyle='round,pad=0.6', alpha=0.6))

    _ = sns.heatmap(data, cmap=cmap3, vmax=1, vmin=-1, center=0, square=True, annot=True, linewidths=.5,
                    linecolor='#f0f0f0', cbar_kws={"shrink": .5}, annot_kws={"size": 8}, fmt=".2f")

# %%
def is_binary(series, unique_tol=2):
    return series.nunique() <= unique_tol

def mixed_corr(df):
    corr_matrix = pd.DataFrame(index=df.columns, columns=df.columns)
    
    for col1 in df.columns:
        for col2 in df.columns:
            try:
                if is_binary(df[col1]) and is_binary(df[col2]):
                    # Both are binary
                    corr_val = df[col1].corr(df[col2], method='pearson')
                elif is_binary(df[col1]) or is_binary(df[col2]):
                    # One is binary and the other is continuous
                    binary_col = col1 if is_binary(df[col1]) else col2
                    cont_col = col2 if is_binary(df[col1]) else col1
                    corr_val = pointbiserialr(df[cont_col], df[binary_col])[0]
                else:
                    # Both are continuous
                    corr_val = df[col1].corr(df[col2])
                
                corr_matrix.at[col1, col2] = corr_val
            except Exception as e:
                print(f"An error occurred while processing {col1} and {col2}: {e}")
    return corr_matrix

def enforce_symmetry(df):
    return (df + df.T)/2

df_numeric = df.select_dtypes(include=['int64', 'float64', 'int32', 'float32'])
mixed_corr_matrix = mixed_corr(df_numeric)

dissimilarity = 1 - abs(mixed_corr_matrix)

# Enforce symmetry
symmetric_dissimilarity = enforce_symmetry(dissimilarity)

# Set diagonal to zero
np.fill_diagonal(symmetric_dissimilarity.values, 0)

# Check for symmetry
print((symmetric_dissimilarity.T == symmetric_dissimilarity).all().all())

# Proceed with clustering
Z = linkage(squareform(symmetric_dissimilarity), 'ward')
# Out:
# True

# %%
# Clusterize the data
threshold = 0.8
labels = fcluster(Z, threshold, criterion='distance')

# Keep the indices to sort labels
labels_order = np.argsort(labels)

# Build a new dataframe with the sorted columns
for idx, i in enumerate(df_numeric.columns[labels_order]):
    if idx == 0:
        clustered = pd.DataFrame(df_numeric[i])
    else:
        df_to_append = pd.DataFrame(df_numeric[i])
        clustered = pd.concat([clustered, df_to_append], axis=1)

clustered_corr = clustered.corr()

#create correlation heat map of numeric features
mask = np.triu(np.ones_like(clustered_corr, dtype=bool))
fig, ax = plt.subplots(figsize=(22, 16), facecolor=main_facecolor)
ax.set_facecolor('#f0f0f0')
ax.grid(False)
ax.set_title('Correlation Heatmap of Numeric Features', fontsize=14, fontweight='semibold', fontfamily='sans-serif', color="#413f42",
             bbox=dict(facecolor='#f0f0f0', edgecolor='#d5d3d6', boxstyle='round,pad=0.6', alpha=0.6))

_ = sns.heatmap(clustered_corr, cmap=cmap3, vmax=1, vmin=-1, center=0, square=True, annot=True, linewidths=.5, linecolor='#f0f0f0', 
            cbar_kws={"shrink": .5}, annot_kws={"size": 8}, fmt=".2f")

# %%
def cramers_v(x, y):
    """Calculate Cramér's V statistic for categorial-categorial association."""
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

def chi2_and_cramers_v(df, target, variables):
    results = []
    for var in variables:
        contingency_table = pd.crosstab(df[target], df[var])
        chi2, p, _, _ = stats.chi2_contingency(contingency_table)
        v = cramers_v(df[var], df[target])
        results.append([var, chi2, p, v])

    results_df = pd.DataFrame(results, columns=['Variable', 'Chi-square statistic', 'P-value', 'Cramers_V'])
    results_df = results_df.sort_values(by='Cramers_V', ascending=False)
    return results_df

cat_cols = df.select_dtypes(include=['object']).columns.tolist()
binary_cols = [col for col in df.columns if df[col].nunique() == 2]
df_cat_bin = df[cat_cols + binary_cols]

# Build the association matrix
cat_assoc_matrix = pd.DataFrame(index=df_cat_bin.columns, columns=df_cat_bin.columns)
for col1 in df_cat_bin.columns:
    for col2 in df_cat_bin.columns:
        cat_assoc_matrix.at[col1, col2] = cramers_v(df_cat_bin[col1], df_cat_bin[col2])

#plot heatmap
fig, ax = plt.subplots(figsize=(16, 10), facecolor=main_facecolor)
ax.set_facecolor('#f0f0f0')
ax.grid(False)
ax.set_title('Correlation Heatmap of Categorical Features', fontsize=14, fontweight='semibold', fontfamily='sans-serif', color="#413f42",
                bbox=dict(facecolor='#f0f0f0', edgecolor='#d5d3d6', boxstyle='round,pad=0.6', alpha=0.6))

_ = sns.heatmap(cat_assoc_matrix.astype(float), cmap=cmap3, vmax=1, vmin=0, center=0, square=True, annot=True, linewidths=.5, linecolor='#f0f0f0',
            cbar_kws={"shrink": .5}, annot_kws={"size": 8}, fmt=".2f")

# %%
# Find where the absolute correlations are above a certain threshold (e.g., greater than 0.7)
high_assoc_var = np.where(cat_assoc_matrix > 0.35)

# Get the indices for highly correlated variables
high_assoc_var_indices = np.unique(np.concatenate(high_assoc_var))

# Get the variable names for highly correlated variables
high_assoc_var_pairs = [(cat_assoc_matrix.index[x], cat_assoc_matrix.columns[y]) for x, y in zip(*high_assoc_var) if x != y]


high_assoc_var_pairs
# Out:
# [('Living_With', 'Is_Parent'),
#  ('AcceptedCmp3', 'AcceptedAnyCmp'),
#  ('AcceptedCmp4', 'AcceptedAnyCmp'),
#  ('AcceptedCmp5', 'AcceptedCmp1'),
#  ('AcceptedCmp5', 'AcceptedAnyCmp'),
#  ('AcceptedCmp1', 'AcceptedCmp5'),
#  ('AcceptedCmp1', 'AcceptedAnyCmp'),
#  ('Response', 'AcceptedAnyCmp'),
#  ('Is_Parent', 'Living_With'),
#  ('AcceptedAnyCmp', 'AcceptedCmp3'),
#  ('AcceptedAnyCmp', 'AcceptedCmp4'),
#  ('AcceptedAnyCmp', 'AcceptedCmp5'),
#  ('AcceptedAnyCmp', 'AcceptedCmp1'),
#  ('AcceptedAnyCmp', 'Response')]

# %%
plt.figure(figsize=(15.5,4))

_ = dendrogram(Z, labels=df_numeric.columns, orientation='top', 
           leaf_rotation=90)

# %%
# Create spending to income ratio
df['Spending_to_Income_Ratio'] = df['Total_Spending'] / df['Income']

# Check for NaN or Inf values
df['Spending_to_Income_Ratio'].replace(to_replace=np.nan, value=0, inplace=True)

df['Income_Category'] = pd.qcut(df['Income'], q=3, labels=None)


df['Age_Category'] = pd.qcut(df['Age'], q=7, labels=None)

#Change values on Marital_Status: Widow and Divorced --> Usedto_Married
df['Marital_Status2'] = df['Marital_Status'].replace(['Widow', 'Divorced'], 'Was_Married')

#Change values on Marital_Status: Married and Together --> Married_or_Together
df['Marital_Status2'] = df['Marital_Status2'].replace(['Married', 'Together'], 'Married_or_Together')

#group month joined to Q1, Q2, Q3
df['Month_Joined2'] = df['Month_Joined'].replace(['Jan', 'Feb', 'Mar'], 'Q1')
df['Month_Joined2'] = df['Month_Joined2'].replace(['Apr', 'May', 'Jun'], 'Q2')
df['Month_Joined2'] = df['Month_Joined2'].replace(['Jul', 'Aug', 'Sep'], 'Q3')
df['Month_Joined2'] = df['Month_Joined2'].replace(['Oct', 'Nov', 'Dec'], 'Q4')

#define total_spending to tenure ratio
df['Spend_to_Tenure_Ratio'] = df['Total_Spending'] / df['Customer_Tenure']

df['Purchase_to_Tenure_Ratio'] =  df['Total_Purchases'] / df['Customer_Tenure']

#replace customer_tenure == 0 to 1
df['Customer_Tenure'] = df['Customer_Tenure'].replace(0, 1)

#create is_widow
df['is_widow'] = df['Marital_Status'] == 'Widow'

#define income to age ratio
df['Income_to_Age_Ratio'] = df['Income'] / df['Age']

#define is_below_graduate (2n cycle and basic)
df['is_below_graduate'] = df['Education'].isin(['2n Cycle', 'Basic'])

#define age density
df['Age_Density'] = df['Age'].map(df['Age'].value_counts(normalize=True))
#create is_age_above60 
df['is_age_above60'] = df['Age'] > 60

#define income to tenure ratio
df['Income_to_Tenure_Ratio'] = df['Income'] / df['Customer_Tenure']

df['Income_to_Tenure_Age_Ratio'] = df['Income'] / df['Customer_Tenure'] / df['Age']

# %%
selected_catvars = ['RFM_Segment', 'Age_Category', 'Income_Category', 'Marital_Status2']
selected_binvars = ['Response', 'Is_Parent', 'is_widow']
selected_numvars = ['Recency_Score',  'Age', 'Avg_RFM', 'Income_to_Tenure_Age_Ratio']

df_filtered = df[selected_catvars + selected_numvars + selected_binvars]
df_filtered[selected_binvars] = df_filtered[selected_binvars].astype(bool)

# Plot correlation matrix for selected numerical variables
corr_numvars = df_filtered[selected_numvars].corr()
plot_heatmap(corr_numvars, 'Correlation Heatmap of Selected Numerical Features', figsize=(20, 14))

df_cat_bin = df[selected_catvars + selected_binvars]
# Build the association matrix for categorical and binary variables
cat_assoc_matrix = pd.DataFrame(index=df_cat_bin.columns, columns=df_cat_bin.columns)
for col1 in df_cat_bin.columns:
    for col2 in df_cat_bin.columns:
        cat_assoc_matrix.at[col1, col2] = cramers_v(df_cat_bin[col1], df_cat_bin[col2])

# Plot heatmap for categorical and binary variables
plot_heatmap(cat_assoc_matrix.astype(float), 'Correlation Heatmap of Categorical and Binary Features')

# %%
def fit_and_evaluate(df_filtered, cluster_selection_method='leaf', umap_combine_method='intersection_union_mapper', n_neighbors=20, 
                    min_cluster_size=100, min_samples=15, colormap="tab10"):
    from matplotlib.colors import ListedColormap
    clf = DenseClus(
        random_state=42,
        cluster_selection_method=cluster_selection_method,
        umap_combine_method=umap_combine_method,
        n_neighbors=n_neighbors,
        min_cluster_size=min_cluster_size, 
        min_samples=min_samples
    )

    # Fit the model
    clf.fit(df_filtered)
    
    # Get labels and summarize
    labels = clf.score()  
    cluster_summary = pd.DataFrame(labels).value_counts(normalize=True).reset_index()
    cluster_summary.columns = ['Cluster', 'Proportion']
    cluster_summary = cluster_summary.sort_values(by='Cluster')

    # Coverage and DBCV Score
    embedding = clf.mapper_.embedding_
    coverage = np.sum(labels != -1) / embedding.shape[0]  # -1 labels are noise
    dbcv_score = clf.hdbscan_.relative_validity_
    
    # Prepare color map
    unique_labels = np.unique(labels)
    n_clusters = len(unique_labels)
    sns_palette = sns.color_palette(colormap, n_clusters)
    cmap = ListedColormap(sns_palette)
    
    # Create a Matplotlib figure with 1 row and 2 columns
    fig, axes = plt.subplots(1, 2, figsize=(24, 10))
    title_text = f"Coverage: {coverage:.2f}, DBCV Score: {dbcv_score:.2f}"
    fig.suptitle(title_text, fontsize=14, fontweight='light')
    
    # First Plot: condensed_tree
    clf.hdbscan_.condensed_tree_.plot(
        axis=axes[1],
        select_clusters=True,
        label_clusters=False,
        colorbar=True,
        selection_palette=sns_palette,
    )
    
    # Second Plot: KDE jointplot mimic
    sns.kdeplot(
        x=clf.mapper_.embedding_[:, 0],
        y=clf.mapper_.embedding_[:, 1],
        hue=labels,
        palette=sns_palette,
        fill=True,
        ax=axes[0]
    )
    
    axes[0].scatter(
        clf.mapper_.embedding_[:, 0],
        clf.mapper_.embedding_[:, 1],
        c=labels,
        cmap=cmap,
        s=50,
        alpha=0.6,
        edgecolors='w'
    )
    
    plt.tight_layout()
    plt.show()

    display(cluster_summary)

    return embedding, labels
    
def plot_trustworthiness(df_filtered2, K=30):
    clf = DenseClus(
        random_state=42,
        cluster_selection_method="eom",
        umap_combine_method="intersection_union_mapper",
    )
    clf.fit(df_filtered2)

    numerical_trustworthiness = validation.trustworthiness_vector(source=clf.numerical_umap_._raw_data
                                  ,embedding=clf.numerical_umap_.embedding_
                                  ,max_k=K)

    categorical_trustworthiness = validation.trustworthiness_vector(source=clf.categorical_umap_._raw_data
                                  ,embedding=clf.categorical_umap_.embedding_
                                  ,max_k=K)

    plt.figure(figsize=(8, 6))
    plt.plot(numerical_trustworthiness)
    plt.plot(categorical_trustworthiness)
    plt.xlabel("Value of K")
    plt.ylabel("Trustworthiness score")
    plt.title(f"Trustworthiness at {K}")
    plt.legend(["Numerical T", "Categorical T"], loc="upper right")
    plt.show()

# To use the function, call it with your DataFrame as an argument
# plot_trustworthiness(df_filtered2, K=30)


def plot_dbcv_scores(df):
    # Get dbcv score over k values
    dbcv_scores = []
    k_values = range(10, 20)

    for k in k_values:
        clf = DenseClus(
            random_state=42,
            cluster_selection_method="eom",
            umap_combine_method="intersection_union_mapper",
            n_neighbors=k,
        )

        clf.fit(df_filtered2)
        dbcv_scores.append(clf.hdbscan_.relative_validity_)

    # Plotting
    plt.figure(figsize=(8, 6))
    plt.plot(k_values, dbcv_scores, marker='o', linestyle='-', color='b')
    plt.xlabel("Value of K")
    plt.ylabel("DBCV score")
    plt.title("DBCV score vs. Value of K")
    plt.grid(True)
    plt.xticks(k_values)
    plt.show()

# %%
# selected_catvars = ['RFM_Segment', 'Age_Category', 'Income_Category2']
# selected_binvars = ['Response', 'Is_Parent', 'is_widow']
# selected_numvars = ['Recency_Score', 'Age_Density','Total_Purchase_to_Tenure_Ratio', 'Age', 'Spend_per_Purchase', 'Total_Purchase_Density']

# selected_catvars = ['RFM_Segment', 'Age_Category', 'Income_Category2']
# selected_binvars = ['Response', 'Is_Parent', 'is_widow']
# selected_numvars = ['Recency_Score', 'Age_Density', 'Age', 'Total_Purchase_to_Tenure_Ratio', 'Avg_RFM']

df_filtered2 = df[selected_catvars + selected_numvars + selected_binvars]
df_filtered2[selected_binvars] = df_filtered2[selected_binvars].astype(bool)

# Fit and evaluate
umap_embedding, labels = fit_and_evaluate(df_filtered2, 'eom', 'intersection_union_mapper', n_neighbors=20, colormap='Dark2')

df['Umap_Cluster'] = labels
cluster_profiles = df.groupby('Umap_Cluster').agg({
        'Recency_Score': 'median',
        'Frequency_Score': 'median',
        'Monetary_Score': 'median',
        'Avg_RFM': 'median',
        'Age': 'median',
        'Income': 'median',
        'Is_Parent': lambda x: x.value_counts().index[0],
        'Generation': lambda x: x.value_counts().index[0],
        'RFM_Segment': lambda x: x.value_counts().index[0:1],
        'Living_With': lambda x: x.value_counts().index[0],
        'Marital_Status': lambda x: x.value_counts().index[0],
        'Education': lambda x: x.value_counts().index[0]
    }).reset_index()

cluster_profiles.set_index('Umap_Cluster')
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
#    Cluster  Proportion
# 1        0    0.266758
# 0        1    0.461924
# 3        2    0.084359
# 4        3    0.069767
# 2        4    0.117191
#               Recency_Score  Frequency_Score  Monetary_Score   Avg_RFM   Age  \
# Umap_Cluster
# 0                       1.0              4.0             4.0  3.333333  55.0
# 1                       3.0              3.0             3.0  3.666667  53.0
# 2                       3.0              1.0             1.0  2.000000  51.0
# 3                       5.0              1.0             1.0  2.333333  41.0
# 4                       5.0              2.0             1.0  2.666667  56.0
#
#                Income  Is_Parent    Generation RFM_Segment  \
# Umap_Cluster
# 0             62503.0          1  Baby_Boomers     At Risk
# 1             58116.0          1  Generation_X        Lost
# 2             33039.0          1  Generation_X   Promising
# 3             31761.0          1  Generation_X         New
# 4             38285.0          1  Generation_X         New
#
#                       Living_With Marital_Status   Education
# Umap_Cluster
# 0                      With_Teens        Married  Graduation
# 1                           Alone        Married  Graduation
# 2                       With_Kids        Married  Graduation
# 3                       With_Kids        Married  Graduation
# 4             With_Kids_and_Teens        Married  Graduation

# %%
from umap import validation

# %%
plot_trustworthiness(df_filtered2, K=30)
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(

# %%
selected_catvars = ['RFM_Segment', 'Age_Category', 'Income_Category']
selected_binvars = ['Response', 'Is_Parent', 'is_widow']
selected_numvars = ['Recency_Score',  'Age', 'Total_Purchase_to_Tenure_Ratio', 'Avg_RFM']

df_filtered2 = df[selected_catvars + selected_numvars + selected_binvars]
df_filtered2[selected_binvars] = df_filtered2[selected_binvars].astype(bool)

# Fit and evaluate
umap_embedding, labels = fit_and_evaluate(df_filtered2, 'eom', 'intersection_union_mapper', n_neighbors=15, colormap='Dark2')

df['Umap_Cluster'] = labels
cluster_profiles = df.groupby('Umap_Cluster').agg({
        'Recency_Score': 'median',
        'Frequency_Score': 'median',
        'Monetary_Score': 'median',
        'Avg_RFM': 'median',
        'Age': 'median',
        'Income': 'median',
        'Is_Parent': lambda x: x.value_counts().index[0],
        'Generation': lambda x: x.value_counts().index[0],
        'RFM_Segment': lambda x: x.value_counts().index[0:1],
        'Living_With': lambda x: x.value_counts().index[0],
        'Marital_Status': lambda x: x.value_counts().index[0],
        'Education': lambda x: x.value_counts().index[0]
    }).reset_index()

cluster_profiles.set_index('Umap_Cluster')
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
#    Cluster  Proportion
# 0        0    0.265846
# 1        1    0.189694
# 4        2    0.082079
# 2        3    0.149111
# 6        4    0.055176
# 5        5    0.056088
# 7        6    0.053352
# 3        7    0.148655
#               Recency_Score  Frequency_Score  Monetary_Score   Avg_RFM   Age  \
# Umap_Cluster
# 0                       1.0              4.0             4.0  3.333333  55.0
# 1                       5.0              2.0             1.0  2.666667  51.0
# 2                       3.0              1.0             1.0  2.000000  51.0
# 3                       4.0              4.0             4.0  3.666667  68.0
# 4                       2.0              2.0             2.0  2.000000  37.0
# 5                       4.0              5.0             5.0  4.333333  45.0
# 6                       3.0              3.0             3.0  3.333333  58.0
# 7                       3.0              3.0             3.0  3.000000  49.0
#
#                Income  Is_Parent    Generation RFM_Segment Living_With  \
# Umap_Cluster
# 0             62745.0          1  Baby_Boomers     At Risk  With_Teens
# 1             35734.5          1  Generation_X         New   With_Kids
# 2             32964.0          1  Generation_X   Promising   With_Kids
# 3             64831.0          1  Baby_Boomers        Lost       Alone
# 4             35388.0          1   Millennials        Lost   With_Kids
# 5             75012.0          0  Generation_X   Champions       Alone
# 6             54456.0          1  Baby_Boomers        Lost  With_Teens
# 7             46939.5          1  Generation_X        Lost   With_Kids
#
#              Marital_Status   Education
# Umap_Cluster
# 0                   Married  Graduation
# 1                   Married  Graduation
# 2                   Married  Graduation
# 3                   Married  Graduation
# 4                   Married  Graduation
# 5                   Married  Graduation
# 6                   Married  Graduation
# 7                   Married  Graduation

# %%
plot_trustworthiness(df_filtered2, K=30)
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(

# %%
selected_catvars = ['RFM_Segment', 'Age_Category', 'Income_Category']
selected_binvars = ['Response', 'Is_Parent', 'is_widow']
selected_numvars = ['Recency_Score',  'Age', 'Total_Purchase_to_Tenure_Ratio', 'Avg_RFM', 'NumWebVisitsMonth']

df_filtered2 = df[selected_catvars + selected_numvars + selected_binvars]
df_filtered2[selected_binvars] = df_filtered2[selected_binvars].astype(bool)

# Fit and evaluate
umap_embedding, labels = fit_and_evaluate(df_filtered2, 'eom', 'intersection_union_mapper', n_neighbors=17, colormap='Dark2')

df['Umap_Cluster'] = labels
cluster_profiles = df.groupby('Umap_Cluster').agg({
        'Recency_Score': 'median',
        'Frequency_Score': 'median',
        'Monetary_Score': 'median',
        'Avg_RFM': 'median',
        'Age': 'median',
        'Income': 'median',
        'Is_Parent': lambda x: x.value_counts().index[0],
        'Generation': lambda x: x.value_counts().index[0],
        'RFM_Segment': lambda x: x.value_counts().index[0:1],
        'Living_With': lambda x: x.value_counts().index[0],
        'Marital_Status': lambda x: x.value_counts().index[0],
        'Education': lambda x: x.value_counts().index[0]
    }).reset_index()

cluster_profiles.set_index('Umap_Cluster')
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
#    Cluster  Proportion
# 1        0    0.267214
# 0        1    0.462380
# 3        2    0.082079
# 2        3    0.188326
#               Recency_Score  Frequency_Score  Monetary_Score   Avg_RFM   Age  \
# Umap_Cluster
# 0                       1.0              4.0             4.0  3.333333  55.0
# 1                       3.0              3.0             3.0  3.666667  53.0
# 2                       3.0              1.0             1.0  2.000000  51.0
# 3                       5.0              2.0             1.0  2.666667  50.0
#
#                Income  Is_Parent    Generation RFM_Segment Living_With  \
# Umap_Cluster
# 0             62624.0          1  Baby_Boomers     At Risk  With_Teens
# 1             58166.5          1  Generation_X        Lost       Alone
# 2             32964.0          1  Generation_X   Promising   With_Kids
# 3             35765.0          1  Generation_X         New   With_Kids
#
#              Marital_Status   Education
# Umap_Cluster
# 0                   Married  Graduation
# 1                   Married  Graduation
# 2                   Married  Graduation
# 3                   Married  Graduation

# %%
plot_trustworthiness(df_filtered2, K=30)
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(

# %%
# To use the function, call it with your DataFrame as an argument
plot_dbcv_scores(df_filtered2)
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\spectral.py:260: UserWarning: WARNING: spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(

# %% [markdown]
# # Exploring Cluster Profiles

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 8))
ax.set_title('Age Distribution by Cluster', fontsize=14, fontweight='semibold', color="#413f42")
ax.set_facecolor('#f5f5f5')
clusters = [0, 1, 2, 3, 4, 5]
colors = ['#1d9643', '#4a68a3', '#d472e8', '#eba2a2', '#ab3063']

for segment, color in zip(clusters, colors):
    sns.kdeplot(data=df[df['Umap_Cluster'] == segment]['Age'], color=color, ax=ax, label=segment, linewidth=1)

ax.set_xlabel('Age', fontsize=14)
ax.set_ylabel('Density', fontsize=14)
ax.legend(loc='upper right', title='Cluster')
plt.tight_layout()
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 8))
ax.set_title('Age Distribution by Cluster', fontsize=14, fontweight='semibold', color="#413f42")
ax.set_facecolor('#f5f5f5')
clusters = [0, 1, 2, 3, 4, 5]
colors = ['#1d9643', '#4a68a3', '#d472e8', '#eba2a2', '#ab3063']

for segment, color in zip(clusters, colors):
    sns.kdeplot(data=df[df['Umap_Cluster'] == segment]['Age'], color=color, ax=ax, label=segment, linewidth=1)

ax.set_xlabel('Age', fontsize=14)
ax.set_ylabel('Density', fontsize=14)
ax.legend(loc='upper right', title='Cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hyperparameter Tuning

# %%
selected_catvars = ['RFM_Segment', 'Age_Category', 'Income_Category2']
selected_binvars = ['Response', 'Is_Parent', 'is_widow']
selected_numvars = ['Recency_Score',  'Age', 'Total_Purchase_to_Tenure_Ratio', 'Avg_RFM']

df_filtered2 = df[selected_catvars + selected_numvars + selected_binvars]
df_filtered2[selected_binvars] = df_filtered2[selected_binvars].astype(bool)

# Fit and evaluate
umap_embedding, labels = fit_and_evaluate(df_filtered2, 'eom', 'intersection_union_mapper', n_neighbors=15, colormap='Dark2')

df['Umap_Cluster'] = labels
cluster_profiles = df.groupby('Umap_Cluster').agg({
        'Recency_Score': 'median',
        'Frequency_Score': 'median',
        'Monetary_Score': 'median',
        'Avg_RFM': 'median',
        'Age': 'median',
        'Income': 'median',
        'Is_Parent': lambda x: x.value_counts().index[0],
        'Generation': lambda x: x.value_counts().index[0],
        'RFM_Segment': lambda x: x.value_counts().index[0:1],
        'Living_With': lambda x: x.value_counts().index[0],
        'Marital_Status': lambda x: x.value_counts().index[0],
        'Education': lambda x: x.value_counts().index[0]
    }).reset_index()

cluster_profiles.set_index('Umap_Cluster')
# Out:
#    Cluster  Proportion
# 0        0    0.265846
# 1        1    0.189694
# 4        2    0.082079
# 2        3    0.149111
# 6        4    0.055176
# 5        5    0.056088
# 7        6    0.053352
# 3        7    0.148655
#               Recency_Score  Frequency_Score  Monetary_Score   Avg_RFM   Age  \
# Umap_Cluster
# 0                       1.0              4.0             4.0  3.333333  55.0
# 1                       5.0              2.0             1.0  2.666667  51.0
# 2                       3.0              1.0             1.0  2.000000  51.0
# 3                       4.0              4.0             4.0  3.666667  68.0
# 4                       2.0              2.0             2.0  2.000000  37.0
# 5                       4.0              5.0             5.0  4.333333  45.0
# 6                       3.0              3.0             3.0  3.333333  58.0
# 7                       3.0              3.0             3.0  3.000000  49.0
#
#                Income  Is_Parent    Generation RFM_Segment Living_With  \
# Umap_Cluster
# 0             62745.0          1  Baby_Boomers     At Risk  With_Teens
# 1             35734.5          1  Generation_X         New   With_Kids
# 2             32964.0          1  Generation_X   Promising   With_Kids
# 3             64831.0          1  Baby_Boomers        Lost       Alone
# 4             35388.0          1   Millennials        Lost   With_Kids
# 5             75012.0          0  Generation_X   Champions       Alone
# 6             54456.0          1  Baby_Boomers        Lost  With_Teens
# 7             46939.5          1  Generation_X        Lost   With_Kids
#
#              Marital_Status   Education
# Umap_Cluster
# 0                   Married  Graduation
# 1                   Married  Graduation
# 2                   Married  Graduation
# 3                   Married  Graduation
# 4                   Married  Graduation
# 5                   Married  Graduation
# 6                   Married  Graduation
# 7                   Married  Graduation

# %%
plot_dbcv_scores(df_filtered2)
# Out:
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\spectral.py:260: UserWarning: WARNING: spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\ramdh\anaconda3\envs\clustering_env\lib\site-packages\umap\umap_.py:1802: UserWarning: gradient function is not yet implemented for dice distance metric; inverse_transform will be unavailable
#   warn(

# %%
import hdbscan
import optuna
import numpy as np
from sklearn.metrics import pairwise_distances
from hyperopt import hp

def tune_hdbscan(umap_embedding, n_trials=100, min_cluster_start=0.01, min_cluster_end=0.15,
                 min_samples_start=0.01, min_samples_end=0.15, max_epsilon=None):
    n_rows = umap_embedding.shape[0]

    # Define the search space
    space = {
        'min_cluster_size': hp.quniform('min_cluster_size', int(n_rows * min_cluster_start),
                                         int(n_rows * min_cluster_end), 1),
        'min_samples': hp.quniform('min_samples', int(n_rows * min_samples_start),
                                   int(n_rows * min_samples_end), 1),
        'cluster_selection_method': hp.choice('cluster_selection_method', ['eom']),
        'metric': hp.choice('metric', ['euclidean', 'manhattan'])
    }

    def objective(trial):
        # Use trial.suggest_int to sample values from the defined search space
        min_cluster_number = trial.suggest_int("min_cluster_size", 40, 300, 5)
        min_samples_number = trial.suggest_int("min_samples", 5, 50, 1)
        
        if max_epsilon is not None:
            cluster_selection_epsilon_number = trial.suggest_float("cluster_selection_epsilon", 0, max_epsilon)
            hdb_model = hdbscan.HDBSCAN(min_cluster_size=min_cluster_number,
                    min_samples=min_samples_number,
                    cluster_selection_epsilon=cluster_selection_epsilon_number,
                    gen_min_span_tree=True).fit(umap_embedding)
        else:
            hdb_model = hdbscan.HDBSCAN(min_cluster_size=min_cluster_number,
                    min_samples=min_samples_number,
                    gen_min_span_tree=True).fit(umap_embedding)

        score = hdb_model.relative_validity_

        return score


    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=n_trials)

    best_model_params = study.best_params

    print("Best parameters: ", best_model_params)

    if max_epsilon is not None:
        hdb_model = hdbscan.HDBSCAN(min_cluster_size=best_model_params['min_cluster_size'],
                                    min_samples=best_model_params['min_samples'],
                                    cluster_selection_epsilon=best_model_params['cluster_selection_epsilon'],
                                    gen_min_span_tree=True).fit(umap_embedding)
    else:
        hdb_model = hdbscan.HDBSCAN(min_cluster_size=best_model_params['min_cluster_size'],
                                    min_samples=best_model_params['min_samples'],
                                    gen_min_span_tree=True).fit(umap_embedding)

    return hdb_model

tuned_hdb_model = tune_hdbscan(umap_embedding, n_trials=600, min_cluster_start=0.01, min_cluster_end=0.15,
                                min_samples_start=0.01, min_samples_end=0.15, max_epsilon=None)
# Out:
# [I 2023-09-04 18:43:08,785] A new study created in memory with name: no-name-d784e317-c3be-4a2a-8d3e-f19a1b49ab5a
# [I 2023-09-04 18:43:08,861] Trial 0 finished with value: 0.6271138102244139 and parameters: {'min_cluster_size': 220, 'min_samples': 5}. Best is trial 0 with value: 0.6271138102244139.
# [I 2023-09-04 18:43:08,934] Trial 1 finished with value: 0.6390781357572958 and parameters: {'min_cluster_size': 80, 'min_samples': 8}. Best is trial 1 with value: 0.6390781357572958.
# [I 2023-09-04 18:43:09,009] Trial 2 finished with value: 0.4204489636265139 and parameters: {'min_cluster_size': 85, 'min_samples': 39}. Best is trial 1 with value: 0.6390781357572958.
# [I 2023-09-04 18:43:09,083] Trial 3 finished with value: 0.4067340661103476 and parameters: {'min_cluster_size': 85, 'min_samples': 43}. Best is trial 1 with value: 0.6390781357572958.
# [I 2023-09-04 18:43:09,158] Trial 4 finished with value: 0.6752929378320501 and parameters: {'min_cluster_size': 50, 'min_samples': 22}. Best is trial 4 with value: 0.6752929378320501.
# [I 2023-09-04 18:43:09,231] Trial 5 finished with value: 0.636232165043608 and parameters: {'min_cluster_size': 175, 'min_samples': 37}. Best is trial 4 with value: 0.6752929378320501.
# [I 2023-09-04 18:43:09,303] Trial 6 finished with value: 0.6082758534891574 and parameters: {'min_cluster_size': 215, 'min_samples': 25}. Best is trial 4 with value: 0.6752929378320501.
# [I 2023-09-04 18:43:09,378] Trial 7 finished with value: 0.48204503833864887 and parameters: {'min_cluster_size': 65, 'min_samples': 37}. Best is trial 4 with value: 0.6752929378320501.
# [I 2023-09-04 18:43:09,454] Trial 8 finished with value: 0.4340926225789804 and parameters: {'min_cluster_size': 290, 'min_samples': 46}. Best is trial 4 with value: 0.6752929378320501.
# [I 2023-09-04 18:43:09,525] Trial 9 finished with value: 0.6424416317320677 and parameters: {'min_cluster_size': 265, 'min_samples': 10}. Best is trial 4 with value: 0.6752929378320501.
# [I 2023-09-04 18:43:09,603] Trial 10 finished with value: 0.692914394994715 and parameters: {'min_cluster_size': 135, 'min_samples': 21}. Best is trial 10 with value: 0.692914394994715.
# [I 2023-09-04 18:43:09,685] Trial 11 finished with value: 0.692914394994715 and parameters: {'min_cluster_size': 135, 'min_samples': 21}. Best is trial 10 with value: 0.692914394994715.
# [I 2023-09-04 18:43:09,771] Trial 12 finished with value: 0.5079825541131562 and parameters: {'min_cluster_size': 135, 'min_samples': 17}. Best is trial 10 with value: 0.692914394994715.
# [I 2023-09-04 18:43:09,857] Trial 13 finished with value: 0.6934705361030359 and parameters: {'min_cluster_size': 135, 'min_samples': 31}. Best is trial 13 with value: 0.6934705361030359.
# [I 2023-09-04 18:43:09,937] Trial 14 finished with value: 0.6192622960665637 and parameters: {'min_cluster_size': 130, 'min_samples': 30}. Best is trial 13 with value: 0.6934705361030359.
# [I 2023-09-04 18:43:10,017] Trial 15 finished with value: 0.6192622960665637 and parameters: {'min_cluster_size': 175, 'min_samples': 30}. Best is trial 13 with value: 0.6934705361030359.
# [I 2023-09-04 18:43:10,102] Trial 16 finished with value: 0.7152264710299802 and parameters: {'min_cluster_size': 115, 'min_samples': 16}. Best is trial 16 with value: 0.7152264710299802.
# [I 2023-09-04 18:43:10,181] Trial 17 finished with value: 0.721866356483206 and parameters: {'min_cluster_size': 115, 'min_samples': 14}. Best is trial 17 with value: 0.721866356483206.
# [I 2023-09-04 18:43:10,260] Trial 18 finished with value: 0.6489548158383631 and parameters: {'min_cluster_size': 105, 'min_samples': 15}. Best is trial 17 with value: 0.721866356483206.
# [I 2023-09-04 18:43:10,342] Trial 19 finished with value: 0.4132003688009634 and parameters: {'min_cluster_size': 40, 'min_samples': 14}. Best is trial 17 with value: 0.721866356483206.
# [I 2023-09-04 18:43:10,425] Trial 20 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:10,505] Trial 21 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:10,583] Trial 22 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 160, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:10,660] Trial 23 finished with value: 0.7001487795688572 and parameters: {'min_cluster_size': 105, 'min_samples': 5}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:10,740] Trial 24 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 155, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:10,821] Trial 25 finished with value: 0.6877075784477383 and parameters: {'min_cluster_size': 100, 'min_samples': 18}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:10,902] Trial 26 finished with value: 0.40495363758180875 and parameters: {'min_cluster_size': 70, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:10,979] Trial 27 finished with value: 0.4378715043435186 and parameters: {'min_cluster_size': 200, 'min_samples': 19}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,058] Trial 28 finished with value: 0.5649111796017217 and parameters: {'min_cluster_size': 190, 'min_samples': 26}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,139] Trial 29 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,220] Trial 30 finished with value: 0.6240266477116095 and parameters: {'min_cluster_size': 245, 'min_samples': 6}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,304] Trial 31 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,384] Trial 32 finished with value: 0.7009232329759439 and parameters: {'min_cluster_size': 150, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,469] Trial 33 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,550] Trial 34 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,629] Trial 35 finished with value: 0.6967035408237545 and parameters: {'min_cluster_size': 75, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,708] Trial 36 finished with value: 0.4687826775588348 and parameters: {'min_cluster_size': 60, 'min_samples': 5}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,792] Trial 37 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 90, 'min_samples': 23}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,875] Trial 38 finished with value: 0.5059680455265861 and parameters: {'min_cluster_size': 150, 'min_samples': 19}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:11,957] Trial 39 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,038] Trial 40 finished with value: 0.7152264710299802 and parameters: {'min_cluster_size': 120, 'min_samples': 16}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,117] Trial 41 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,198] Trial 42 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 110, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,294] Trial 43 finished with value: 0.6368807779172629 and parameters: {'min_cluster_size': 80, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,374] Trial 44 finished with value: 0.7101000277988608 and parameters: {'min_cluster_size': 145, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,460] Trial 45 finished with value: 0.4314229608644469 and parameters: {'min_cluster_size': 185, 'min_samples': 48}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,540] Trial 46 finished with value: 0.5033781812133602 and parameters: {'min_cluster_size': 165, 'min_samples': 42}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,623] Trial 47 finished with value: 0.6494029065702651 and parameters: {'min_cluster_size': 125, 'min_samples': 34}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,706] Trial 48 finished with value: 0.6663351691884569 and parameters: {'min_cluster_size': 60, 'min_samples': 24}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,787] Trial 49 finished with value: 0.6561688658095038 and parameters: {'min_cluster_size': 135, 'min_samples': 20}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,869] Trial 50 finished with value: 0.6231681043658688 and parameters: {'min_cluster_size': 85, 'min_samples': 17}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:12,945] Trial 51 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,036] Trial 52 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,120] Trial 53 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 140, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,199] Trial 54 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,278] Trial 55 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 115, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,357] Trial 56 finished with value: 0.6489548158383631 and parameters: {'min_cluster_size': 105, 'min_samples': 15}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,435] Trial 57 finished with value: 0.6424416317320677 and parameters: {'min_cluster_size': 300, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,513] Trial 58 finished with value: 0.5466506119243053 and parameters: {'min_cluster_size': 50, 'min_samples': 16}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,595] Trial 59 finished with value: 0.6366108443094922 and parameters: {'min_cluster_size': 80, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,672] Trial 60 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 95, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,752] Trial 61 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,830] Trial 62 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,909] Trial 63 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 130, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:13,989] Trial 64 finished with value: 0.620909903833974 and parameters: {'min_cluster_size': 70, 'min_samples': 15}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,065] Trial 65 finished with value: 0.7001487795688572 and parameters: {'min_cluster_size': 100, 'min_samples': 5}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,144] Trial 66 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,227] Trial 67 finished with value: 0.6877075784477383 and parameters: {'min_cluster_size': 90, 'min_samples': 18}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,305] Trial 68 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 110, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,383] Trial 69 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 145, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,462] Trial 70 finished with value: 0.6420034866157933 and parameters: {'min_cluster_size': 235, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,540] Trial 71 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,620] Trial 72 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,698] Trial 73 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,775] Trial 74 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 160, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,860] Trial 75 finished with value: 0.7009232329759439 and parameters: {'min_cluster_size': 130, 'min_samples': 6}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:14,941] Trial 76 finished with value: 0.5105895342780193 and parameters: {'min_cluster_size': 100, 'min_samples': 17}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,022] Trial 77 finished with value: 0.620909903833974 and parameters: {'min_cluster_size': 70, 'min_samples': 15}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,100] Trial 78 finished with value: 0.7009232329759439 and parameters: {'min_cluster_size': 140, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,182] Trial 79 finished with value: 0.6374027537916775 and parameters: {'min_cluster_size': 85, 'min_samples': 21}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,262] Trial 80 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,339] Trial 81 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,417] Trial 82 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,499] Trial 83 finished with value: 0.6069582698755559 and parameters: {'min_cluster_size': 80, 'min_samples': 27}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,577] Trial 84 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 110, 'min_samples': 6}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,658] Trial 85 finished with value: 0.4168695396810623 and parameters: {'min_cluster_size': 55, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,739] Trial 86 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,821] Trial 87 finished with value: 0.721866356483206 and parameters: {'min_cluster_size': 115, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,902] Trial 88 finished with value: 0.3743644695171509 and parameters: {'min_cluster_size': 40, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:15,984] Trial 89 finished with value: 0.7116205998225613 and parameters: {'min_cluster_size': 75, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,067] Trial 90 finished with value: 0.6784890128581789 and parameters: {'min_cluster_size': 130, 'min_samples': 32}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,148] Trial 91 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,227] Trial 92 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,308] Trial 93 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,386] Trial 94 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,470] Trial 95 finished with value: 0.7098798440950693 and parameters: {'min_cluster_size': 140, 'min_samples': 16}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,548] Trial 96 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,628] Trial 97 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 110, 'min_samples': 6}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,709] Trial 98 finished with value: 0.6947382770228917 and parameters: {'min_cluster_size': 75, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,789] Trial 99 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,870] Trial 100 finished with value: 0.6366108443094922 and parameters: {'min_cluster_size': 85, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:16,952] Trial 101 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,032] Trial 102 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 100, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,112] Trial 103 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,192] Trial 104 finished with value: 0.41324530337080795 and parameters: {'min_cluster_size': 65, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,271] Trial 105 finished with value: 0.6369474819688692 and parameters: {'min_cluster_size': 85, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,349] Trial 106 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,430] Trial 107 finished with value: 0.6489548158383631 and parameters: {'min_cluster_size': 90, 'min_samples': 15}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,514] Trial 108 finished with value: 0.636232165043608 and parameters: {'min_cluster_size': 130, 'min_samples': 37}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,591] Trial 109 finished with value: 0.7001487795688572 and parameters: {'min_cluster_size': 100, 'min_samples': 5}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,673] Trial 110 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,751] Trial 111 finished with value: 0.6424416317320677 and parameters: {'min_cluster_size': 275, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,831] Trial 112 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,908] Trial 113 finished with value: 0.7009232329759439 and parameters: {'min_cluster_size': 125, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:17,987] Trial 114 finished with value: 0.6424416317320677 and parameters: {'min_cluster_size': 210, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,071] Trial 115 finished with value: 0.5068329158234401 and parameters: {'min_cluster_size': 95, 'min_samples': 40}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,151] Trial 116 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,232] Trial 117 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 135, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,310] Trial 118 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 150, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,391] Trial 119 finished with value: 0.6395074569230523 and parameters: {'min_cluster_size': 80, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,472] Trial 120 finished with value: 0.721866356483206 and parameters: {'min_cluster_size': 105, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,553] Trial 121 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,633] Trial 122 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,715] Trial 123 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,795] Trial 124 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,875] Trial 125 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:18,955] Trial 126 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 140, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,035] Trial 127 finished with value: 0.7009232329759439 and parameters: {'min_cluster_size': 125, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,114] Trial 128 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 95, 'min_samples': 6}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,203] Trial 129 finished with value: 0.6489548158383631 and parameters: {'min_cluster_size': 90, 'min_samples': 15}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,285] Trial 130 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 130, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,366] Trial 131 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,447] Trial 132 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,529] Trial 133 finished with value: 0.721866356483206 and parameters: {'min_cluster_size': 115, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,611] Trial 134 finished with value: 0.7098798440950693 and parameters: {'min_cluster_size': 125, 'min_samples': 16}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,698] Trial 135 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,781] Trial 136 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 135, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,868] Trial 137 finished with value: 0.4212857246871319 and parameters: {'min_cluster_size': 85, 'min_samples': 45}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:19,951] Trial 138 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,030] Trial 139 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,115] Trial 140 finished with value: 0.4944156608814209 and parameters: {'min_cluster_size': 120, 'min_samples': 50}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,201] Trial 141 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,284] Trial 142 finished with value: 0.721866356483206 and parameters: {'min_cluster_size': 115, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,366] Trial 143 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,446] Trial 144 finished with value: 0.7009232329759439 and parameters: {'min_cluster_size': 130, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,530] Trial 145 finished with value: 0.5105895342780193 and parameters: {'min_cluster_size': 120, 'min_samples': 17}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,635] Trial 146 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,714] Trial 147 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,797] Trial 148 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,877] Trial 149 finished with value: 0.6267266924640964 and parameters: {'min_cluster_size': 75, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:20,964] Trial 150 finished with value: 0.6488730217582843 and parameters: {'min_cluster_size': 145, 'min_samples': 35}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,045] Trial 151 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,125] Trial 152 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,207] Trial 153 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,292] Trial 154 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,382] Trial 155 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,471] Trial 156 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,551] Trial 157 finished with value: 0.6424416317320677 and parameters: {'min_cluster_size': 185, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,644] Trial 158 finished with value: 0.6036375369442369 and parameters: {'min_cluster_size': 85, 'min_samples': 29}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,731] Trial 159 finished with value: 0.7112697652640874 and parameters: {'min_cluster_size': 120, 'min_samples': 15}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,812] Trial 160 finished with value: 0.6390781357572958 and parameters: {'min_cluster_size': 80, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,899] Trial 161 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:21,982] Trial 162 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,067] Trial 163 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,149] Trial 164 finished with value: 0.721866356483206 and parameters: {'min_cluster_size': 90, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,230] Trial 165 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,309] Trial 166 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,389] Trial 167 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 130, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,468] Trial 168 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,551] Trial 169 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 100, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,632] Trial 170 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,715] Trial 171 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,799] Trial 172 finished with value: 0.6368978657825617 and parameters: {'min_cluster_size': 80, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,881] Trial 173 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:22,963] Trial 174 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,045] Trial 175 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 110, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,135] Trial 176 finished with value: 0.6367208959780201 and parameters: {'min_cluster_size': 85, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,221] Trial 177 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,303] Trial 178 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,384] Trial 179 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,465] Trial 180 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 100, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,545] Trial 181 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,627] Trial 182 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,720] Trial 183 finished with value: 0.7101000277988608 and parameters: {'min_cluster_size': 135, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,805] Trial 184 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,887] Trial 185 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:23,967] Trial 186 finished with value: 0.5366059870235957 and parameters: {'min_cluster_size': 70, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,050] Trial 187 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,135] Trial 188 finished with value: 0.7132962664482719 and parameters: {'min_cluster_size': 120, 'min_samples': 24}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,218] Trial 189 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 130, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,303] Trial 190 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,388] Trial 191 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 100, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,471] Trial 192 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,554] Trial 193 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,641] Trial 194 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,723] Trial 195 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,808] Trial 196 finished with value: 0.6390781357572958 and parameters: {'min_cluster_size': 85, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,889] Trial 197 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:24,975] Trial 198 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,062] Trial 199 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,150] Trial 200 finished with value: 0.7101000277988608 and parameters: {'min_cluster_size': 170, 'min_samples': 14}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,237] Trial 201 finished with value: 0.6368978657825617 and parameters: {'min_cluster_size': 80, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,324] Trial 202 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,410] Trial 203 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 95, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,504] Trial 204 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,586] Trial 205 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,669] Trial 206 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 100, 'min_samples': 6}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,750] Trial 207 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,833] Trial 208 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,915] Trial 209 finished with value: 0.6368807779172629 and parameters: {'min_cluster_size': 85, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:25,998] Trial 210 finished with value: 0.7048131150133725 and parameters: {'min_cluster_size': 75, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,080] Trial 211 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,165] Trial 212 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,250] Trial 213 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,332] Trial 214 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,417] Trial 215 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 120, 'min_samples': 8}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,499] Trial 216 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,581] Trial 217 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,667] Trial 218 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,751] Trial 219 finished with value: 0.6367208959780201 and parameters: {'min_cluster_size': 85, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,833] Trial 220 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 9}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,914] Trial 221 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:26,997] Trial 222 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:27,081] Trial 223 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 105, 'min_samples': 7}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:27,164] Trial 224 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 11}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:27,258] Trial 225 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 12}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:27,341] Trial 226 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 10}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:27,425] Trial 227 finished with value: 0.6424416317320677 and parameters: {'min_cluster_size': 245, 'min_samples': 13}. Best is trial 20 with value: 0.7223045015994803.
# [I 2023-09-04 18:43:27,510] Trial 228 finished with value: 0.7240000549580758 and parameters: {'min_cluster_size': 90, 'min_samples': 8}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:27,594] Trial 229 finished with value: 0.7240000549580758 and parameters: {'min_cluster_size': 90, 'min_samples': 8}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:27,678] Trial 230 finished with value: 0.6395074569230523 and parameters: {'min_cluster_size': 85, 'min_samples': 7}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:27,760] Trial 231 finished with value: 0.6390781357572958 and parameters: {'min_cluster_size': 80, 'min_samples': 8}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:27,841] Trial 232 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:27,924] Trial 233 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 95, 'min_samples': 8}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,008] Trial 234 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 120, 'min_samples': 10}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,090] Trial 235 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,171] Trial 236 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 105, 'min_samples': 6}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,251] Trial 237 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 11}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,334] Trial 238 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 100, 'min_samples': 8}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,417] Trial 239 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 125, 'min_samples': 12}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,500] Trial 240 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 110, 'min_samples': 13}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,584] Trial 241 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 9}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,667] Trial 242 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 10}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,748] Trial 243 finished with value: 0.6368807779172629 and parameters: {'min_cluster_size': 80, 'min_samples': 11}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,832] Trial 244 finished with value: 0.6368978657825617 and parameters: {'min_cluster_size': 85, 'min_samples': 10}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:28,915] Trial 245 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 9}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,001] Trial 246 finished with value: 0.6970616170560529 and parameters: {'min_cluster_size': 110, 'min_samples': 8}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,087] Trial 247 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 90, 'min_samples': 12}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,170] Trial 248 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 100, 'min_samples': 11}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,255] Trial 249 finished with value: 0.721866356483206 and parameters: {'min_cluster_size': 120, 'min_samples': 14}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,339] Trial 250 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 105, 'min_samples': 10}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,424] Trial 251 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 95, 'min_samples': 11}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,509] Trial 252 finished with value: 0.7105381729151352 and parameters: {'min_cluster_size': 130, 'min_samples': 9}. Best is trial 228 with value: 0.7240000549580758.
# [I 2023-09-04 18:43:29,592] Trial 253 finished with value: 0.7223045015994803 and parameters: {'min_cluster_size': 115, 'min_samples': 12}. Best is trial 228 with value: 0.7240000549580758.
# ...
# [I 2023-09-04 18:43:59,341] Trial 517 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 105, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:43:59,435] Trial 518 finished with value: 0.692914394994715 and parameters: {'min_cluster_size': 140, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:43:59,530] Trial 519 finished with value: 0.47361305513187607 and parameters: {'min_cluster_size': 115, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:43:59,624] Trial 520 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 110, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:43:59,717] Trial 521 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 100, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:43:59,809] Trial 522 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 110, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:43:59,902] Trial 523 finished with value: 0.7132962664482719 and parameters: {'min_cluster_size': 120, 'min_samples': 24}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:43:59,997] Trial 524 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 95, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,090] Trial 525 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 105, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,182] Trial 526 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 120, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,284] Trial 527 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 115, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,393] Trial 528 finished with value: 0.5910300474667438 and parameters: {'min_cluster_size': 105, 'min_samples': 36}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,501] Trial 529 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 110, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,605] Trial 530 finished with value: 0.5059680455265861 and parameters: {'min_cluster_size': 125, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,725] Trial 531 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 100, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,825] Trial 532 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 115, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:00,923] Trial 533 finished with value: 0.6877075784477383 and parameters: {'min_cluster_size': 115, 'min_samples': 18}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,014] Trial 534 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 105, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,105] Trial 535 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 110, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,198] Trial 536 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 95, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,291] Trial 537 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 100, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,384] Trial 538 finished with value: 0.5059680455265861 and parameters: {'min_cluster_size': 130, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,476] Trial 539 finished with value: 0.7132962664482719 and parameters: {'min_cluster_size': 120, 'min_samples': 24}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,569] Trial 540 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 105, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,660] Trial 541 finished with value: 0.6236639237434835 and parameters: {'min_cluster_size': 200, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,751] Trial 542 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 110, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,844] Trial 543 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 115, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:01,937] Trial 544 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 105, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,028] Trial 545 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 110, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,121] Trial 546 finished with value: 0.6381437878513658 and parameters: {'min_cluster_size': 225, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,216] Trial 547 finished with value: 0.48057342272400555 and parameters: {'min_cluster_size': 125, 'min_samples': 47}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,311] Trial 548 finished with value: 0.6887250512803309 and parameters: {'min_cluster_size': 120, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,405] Trial 549 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 115, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,508] Trial 550 finished with value: 0.6792915250626183 and parameters: {'min_cluster_size': 100, 'min_samples': 26}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,604] Trial 551 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 105, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,695] Trial 552 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 110, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,787] Trial 553 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 115, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,881] Trial 554 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 100, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:02,975] Trial 555 finished with value: 0.6877075784477383 and parameters: {'min_cluster_size': 110, 'min_samples': 18}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,068] Trial 556 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 120, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,161] Trial 557 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 105, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,255] Trial 558 finished with value: 0.47361305513187607 and parameters: {'min_cluster_size': 95, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,349] Trial 559 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 115, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,443] Trial 560 finished with value: 0.6662763688753773 and parameters: {'min_cluster_size': 110, 'min_samples': 31}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,538] Trial 561 finished with value: 0.6846979712889374 and parameters: {'min_cluster_size': 125, 'min_samples': 24}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,631] Trial 562 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 100, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,724] Trial 563 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 110, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,819] Trial 564 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 105, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:03,912] Trial 565 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 120, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,016] Trial 566 finished with value: 0.47361305513187607 and parameters: {'min_cluster_size': 115, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,110] Trial 567 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 100, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,204] Trial 568 finished with value: 0.6796444123839672 and parameters: {'min_cluster_size': 40, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,299] Trial 569 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 115, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,393] Trial 570 finished with value: 0.590982633604042 and parameters: {'min_cluster_size': 290, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,487] Trial 571 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 105, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,580] Trial 572 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 95, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,673] Trial 573 finished with value: 0.6561688658095038 and parameters: {'min_cluster_size': 130, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,764] Trial 574 finished with value: 0.6877075784477383 and parameters: {'min_cluster_size': 110, 'min_samples': 18}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,858] Trial 575 finished with value: 0.6752929378320501 and parameters: {'min_cluster_size': 55, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:04,951] Trial 576 finished with value: 0.47361305513187607 and parameters: {'min_cluster_size': 115, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,045] Trial 577 finished with value: 0.5105895342780193 and parameters: {'min_cluster_size': 105, 'min_samples': 17}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,141] Trial 578 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 120, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,238] Trial 579 finished with value: 0.7040164604657214 and parameters: {'min_cluster_size': 110, 'min_samples': 25}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,332] Trial 580 finished with value: 0.6830014893034745 and parameters: {'min_cluster_size': 95, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,432] Trial 581 finished with value: 0.6846979712889374 and parameters: {'min_cluster_size': 125, 'min_samples': 24}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,534] Trial 582 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 110, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,630] Trial 583 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 120, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,728] Trial 584 finished with value: 0.47361305513187607 and parameters: {'min_cluster_size': 100, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,821] Trial 585 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 105, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:05,918] Trial 586 finished with value: 0.6561688658095038 and parameters: {'min_cluster_size': 145, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,013] Trial 587 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 115, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,106] Trial 588 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 105, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,211] Trial 589 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 110, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,304] Trial 590 finished with value: 0.7143654738615395 and parameters: {'min_cluster_size': 120, 'min_samples': 23}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,395] Trial 591 finished with value: 0.5880723246264364 and parameters: {'min_cluster_size': 190, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,493] Trial 592 finished with value: 0.4944156608814209 and parameters: {'min_cluster_size': 115, 'min_samples': 50}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,586] Trial 593 finished with value: 0.6877075784477383 and parameters: {'min_cluster_size': 105, 'min_samples': 18}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,680] Trial 594 finished with value: 0.47361305513187607 and parameters: {'min_cluster_size': 110, 'min_samples': 19}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,773] Trial 595 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 100, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,866] Trial 596 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 115, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:06,958] Trial 597 finished with value: 0.6887250512803309 and parameters: {'min_cluster_size': 120, 'min_samples': 20}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:07,065] Trial 598 finished with value: 0.7225547805963454 and parameters: {'min_cluster_size': 100, 'min_samples': 22}. Best is trial 302 with value: 0.7244071587138804.
# [I 2023-09-04 18:44:07,158] Trial 599 finished with value: 0.7244071587138804 and parameters: {'min_cluster_size': 110, 'min_samples': 21}. Best is trial 302 with value: 0.7244071587138804.
# Best parameters:  {'min_cluster_size': 115, 'min_samples': 21}

# %%
# Fit and evaluate
umap_embedding_opt, labels_opt = fit_and_evaluate(df_filtered2, 'eom', 'intersection_union_mapper', n_neighbors=15, 
                                                min_cluster_size= 115, min_samples=21, colormap='Set1')

df['Umap_Cluster'] = labels_opt
cluster_profiles = df.groupby('Umap_Cluster').agg({
        'Recency_Score': 'median',
        'Frequency_Score': 'median',
        'Monetary_Score': 'median',
        'Avg_RFM': 'median',
        'Age': 'median',
        'Income': 'median',
        'Is_Parent': lambda x: x.value_counts().index[0],
        'Generation': lambda x: x.value_counts().index[0],
        'RFM_Segment': lambda x: x.value_counts().index[0:1],
    }).reset_index()

cluster_profiles.set_index('Umap_Cluster')
# Out:
#    Cluster  Proportion
# 0        0    0.265846
# 2        1    0.189694
# 4        2    0.082079
# 3        3    0.149111
# 1        4    0.202006
# 5        5    0.056088
# 6        6    0.055176
#               Recency_Score  Frequency_Score  Monetary_Score   Avg_RFM   Age  \
# Umap_Cluster
# 0                       1.0              4.0             4.0  3.333333  55.0
# 1                       5.0              2.0             1.0  2.666667  51.0
# 2                       3.0              1.0             1.0  2.000000  51.0
# 3                       4.0              4.0             4.0  3.666667  68.0
# 4                       3.0              3.0             3.0  3.333333  52.0
# 5                       4.0              5.0             5.0  4.333333  45.0
# 6                       2.0              2.0             2.0  2.000000  37.0
#
#                Income  Is_Parent    Generation RFM_Segment
# Umap_Cluster
# 0             62745.0          1  Baby_Boomers     At Risk
# 1             35734.5          1  Generation_X         New
# 2             32964.0          1  Generation_X   Promising
# 3             64831.0          1  Baby_Boomers        Lost
# 4             49681.0          1  Generation_X        Lost
# 5             75012.0          0  Generation_X   Champions
# 6             35388.0          1   Millennials        Lost

# %%
#create crosstab where umap_cluster==5 with is_parent and RFM_Segment
pd.crosstab(df['Umap_Cluster'], df['RFM_Segment'], normalize='columns')
# Out:
# RFM_Segment   At Risk  Champions      Lost       New  Promising
# Umap_Cluster
# 0                 1.0   0.000000  0.000000  0.000000        0.0
# 1                 0.0   0.000000  0.002554  0.985714        0.0
# 2                 0.0   0.000000  0.001277  0.000000        1.0
# 3                 0.0   0.464912  0.280971  0.002381        0.0
# 4                 0.0   0.000000  0.559387  0.011905        0.0
# 5                 0.0   0.535088  0.001277  0.000000        0.0
# 6                 0.0   0.000000  0.154534  0.000000        0.0
